# %% [markdown]
# # Clean the pension fund dataset!
#
# The dataset you're about to work with contains an excerpt of a much larger dataset with all the Danish pension funds' investments. It is provided as a CSV file with the following columns: name of the pension fund, name of the company, invested amount. The separator of the CSV file is the semicolon (;).
#
# Your task is to clean and format the data according to the guidelines below and then write it to a new (!) CSV file.
#
# Please note that the only module you will have to import is Python's built-in CSV module. Some of the tasks can be solved using other modules, but this is totally optional, and you will most probably be able to solve the tasks faster by implementing your own function instead of searching for a corresponding one (be aware that this only counts for this exercise - in other circumstances it may be much better to use existing modules!).
#
# In this exercise, you should focus on breaking the code into several helper functions. Work on making each of the helper functions return the desired output, which in turn involves looking at what exactly you provide as input to the function.
#
# Complete the following tasks - but think about the order in which you do them first!
#
# - Remove any wrong or odd row entries.
# - Read the file into memory.
# - All the columns with the company names begin with 'company_name:'. Remove this, so that the entry only contains the company's name.
# - Write the nice and clean data to another CSV file.
# - In the raw file, the invested sums are formatted in different ways. AkademikerPension is formatted as decimal numbers, and Industriens Pension is in million DKK (e. g. 130 means 130000000). Only PenSam and Velliv are already formatted correctly. All of the sums have to be formatted as non-decimal numbers and as a complete number, e.g. if the investment is 5.9 million DKK, the entry should be 5900000 and nothing else.
#
# For the tasks involving string manipulation, you can find help here: https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/14-Strings-and-Regular-Expressions.ipynb
#
# If you are done with the tasks above, please do the following:
# - Create a dictionary with the name of the pension fund as the key, and a list of lists as the value of each fund. The list should contain the largest invested sum in a single company and the median investment. It should be in the following format: [[company name (str), invested sum (int)], [company name (str), invested sum (int)]] with the entry at index 0 being the company where the corresponding pension fund has invested the largest amount of money.
# - Make sure all your helper functions contain docstrings according to PEP8.

# %%
import csv

filename = "/Users/halla/Documents/Redi school/ReDi_DataAnalytics_Repo/Homework/Halla/Pension fund excercise/pension_fund_data.csv"

with open(filename) as file:
    reader = csv.reader(file)
    
    for row in reader:
        print("row #" + str(reader.line_num)+ str(row))
# Out:
# row #1['pension_fund;company ;invested_amount']
# row #2['AkademikerPension;company_name: ANDRITZ AG;9035889.67000961']
# row #3['AkademikerPension;company_name: Verbund AG;535484.04264']
# row #4['AkademikerPension;company_name: Wienerberger AG;489278.539054215']
# row #5['AkademikerPension;company_name: ams AG;9582835.98899249']
# row #6['AkademikerPension;company_name: Oesterreichische Post AG;283768.092184449']
# row #7['AkademikerPension;company_name: Pendal Group Ltd;1279011.44099595']
# row #8['AkademikerPension;company_name: Asaleo Care Ltd;311739.24']
# row #9['AkademikerPension;company_name: Aristocrat Leisure Ltd;159265.740991766']
# row #10['AkademikerPension;company_name: ALS Ltd;10314327.76']
# row #11['AkademikerPension;company_name: Altium Ltd;14675679.27']
# row #12['AkademikerPension;company_name: AMP Ltd;210881.09']
# row #13['AkademikerPension;company_name: AUST AND NZ BANKING GROUP;15375.58598142']
# row #14['AkademikerPension;company_name: Australia & New Zealand Banking Group Ltd;723352.74']
# row #15['AkademikerPension;company_name: Afterpay Ltd;52173246.8698483']
# row #16['AkademikerPension;company_name: ARB Corp Ltd;1264033.30473119']
# row #17['AkademikerPension;company_name: Aurizon Holdings Ltd;464861.38']
# row #18['AkademikerPension;company_name: BHP Group Ltd;864932.15']
# row #19['AkademikerPension;company_name: BlueScope Steel Ltd;917444.99']
# row #20['AkademikerPension;company_name: Brambles Ltd;27064700.0083148']
# row #21['AkademikerPension;company_name: carsales.com Ltd;7762697.73']
# row #22['AkademikerPension;company_name: Challenger Ltd;102934.07']
# row #23['AkademikerPension;company_name: Sungard AS New Holdings III LLC;86069.3048419842']
# row #24['AkademikerPension;company_name: Superior Energy Services Inc;4876.30308519994']
# row #25['AkademikerPension;company_name: a2 Milk Co Ltd/The;3541279.4']
# row #26['AkademikerPension;company_name: Fisher & Paykel Healthcare Corp Ltd;20645924.7901157']
# row #27['AkademikerPension;company_name: Fletcher Building Ltd;416220.93']
# row #28['AkademikerPension;company_name: SKY Network Television Ltd;94699.0000000001']
# row #29['AkademikerPension;company_name: Xero Ltd;55058026.5397112']
# row #30['AkademikerPension;company_name: Copa Holdings SA;26475067.0386764']
# row #31['AkademikerPension;company_name: Ayala Land Inc;21203523.018685']
# row #32['AkademikerPension;company_name: BANK OF THE PHILIPPINE ISLAN;60200.1842401783']
# row #33['AkademikerPension;company_name: Bank of the Philippine Islands;8026691.23537698']
# row #34['AkademikerPension;company_name: GT Capital Holdings Inc;509884.860641693']
# row #35['AkademikerPension;company_name: FIRST BANCORP PUERTO RICO;23846.623908']
# row #36['AkademikerPension;company_name: First BanCorp/Puerto Rico;4841240.7']
# row #37['AkademikerPension;company_name: Popular Inc;4323906.8552835']
# row #38['AkademikerPension;company_name: Jeronimo Martins SGPS SA;486822.302129009']
# row #39['AkademikerPension;company_name: Alrosa PJSC;804648.459918326']
# row #40['AkademikerPension;company_name: Sberbank of Russia PJSC;19143639.6143176']
# row #41['AkademikerPension;company_name: SKF AB;13273406.6633907']
# row #42['AkademikerPension;company_name: Telefonaktiebolaget LM Ericsson;161110047.305397']
# row #43['AkademikerPension;company_name: Skanska AB;5239693.04']
# row #44['AkademikerPension;company_name: Trelleborg AB;6148926.74']
# row #45['AkademikerPension;company_name: Volvo AB;33971461.6960737']
# row #46['AkademikerPension;company_name: SSAB AB;3869236.51']
# row #47['AkademikerPension;company_name: Skandinaviska Enskilda Banken AB;40280221.8488569']
# row #48['AkademikerPension;company_name: Getinge AB;262223.69']
# row #49['AkademikerPension;company_name: Modern Times Group MTG AB;119935.100307132']
# row #50['AkademikerPension;company_name: Sandvik AB;20269610.1958841']
# row #51['AkademikerPension;company_name: Cellavision AB;2530996.36']
# row #52['AkademikerPension;company_name: BillerudKorsnas AB;5760095.79']
# row #53['AkademikerPension;company_name: INVISIO AB;4402581.34']
# row #54['AkademikerPension;company_name: Fortnox AB;2416749.11']
# row #55['AkademikerPension;company_name: Genovis AB;3483834.05']
# row #56['AkademikerPension;company_name: Xvivo Perfusion AB;4466050.02']
# row #57['AkademikerPension;company_name: Inwido AB;6752577.04']
# row #58['AkademikerPension;company_name: Assa Abloy AB;1388916.78130948']
# row #59['AkademikerPension;company_name: Svenska Handelsbanken AB;3356745.01500966']
# row #60['AkademikerPension;company_name: MIPS AB;11311639.59']
# row #61['AkademikerPension;company_name: Boozt AB;29385069.3']
# row #62['AkademikerPension;company_name: Essity AB;30398980.0542549']
# row #63['AkademikerPension;company_name: Arjo AB;11028859.29']
# row #64['AkademikerPension;company_name: BHG Group AB;3301043.9']
# row #65['AkademikerPension;company_name: Atlas Copco AB;91465322.4580255']
# row #66['AkademikerPension;company_name: Nordic Entertainment Group AB;307669.25']
# row #67['AkademikerPension;company_name: Avanza Bank Holding AB;9177345.22']
# row #68['AkademikerPension;company_name: Evolution AB;18188105.4840355']
# row #69['AkademikerPension;company_name: CELLINK AB;6934256.41']
# row #70['AkademikerPension;company_name: Sweco AB;4264553.86']
# row #71['AkademikerPension;company_name: Epiroc AB;7803832.61']
# row #72['AkademikerPension;company_name: Epiroc AB;124520.4']
# row #73['AkademikerPension;company_name: Boliden AB;44836058.7641073']
# row #74['AkademikerPension;company_name: Boliden AB;798532.976934545']
# row #75['AkademikerPension;company_name: Investor AB;21649734.0530522']
# row #76['AkademikerPension;company_name: Hexagon AB;37652364.8326568']
# row #77['AkademikerPension;company_name: Nibe Industrier AB;9265638.24286147']
# row #78['AkademikerPension;company_name: Jardine Cycle & Carriage Ltd;744690.538458483']
# row #79['AkademikerPension;company_name: Haw Par Corp Ltd;386592.460293828']
# row #80['AkademikerPension;company_name: Great Eastern Holdings Ltd;558906.580424795']
# row #81['AkademikerPension;company_name: Singapore Land Group Ltd;55548.4200422196']
# row #82['AkademikerPension;company_name: DBS GROUP HOLDINGS LTD;761277.584152225']
# row #83['AkademikerPension;company_name: UNITED OVERSEAS BANK LTD;802245.947289922']
# row #84['AkademikerPension;company_name: Delfi Ltd;749057.760569319']
# row #85['AkademikerPension;company_name: City Developments Ltd;25169178.9991298']
# row #86['AkademikerPension;company_name: Singapore Telecommunications Ltd;193105.280146769']
# row #87['AkademikerPension;company_name: Mapletree Industrial Trust;10605050.8080999']
# row #88['AkademikerPension;company_name: Flex Ltd;55165174.5555227']
# row #89['AkademikerPension;company_name: Genting Singapore Ltd;646329.840491241']
# row #90['AkademikerPension;company_name: Kasikornbank PCL;1383396.5507162']
# row #91['AkademikerPension;company_name: Major Cineplex Group PCL;947923.61513256']
# row #92['AkademikerPension;company_name: CP ALL PCL;10424235.6364732']
# row #93['AkademikerPension;company_name: THAI BEVERAGE PCL;660964.383611508']
# row #94['AkademikerPension;company_name: SRI TRANG GLOVES THA-FOREIGN;185088.3842016']
# row #95['AkademikerPension;company_name: Sri Trang Gloves Thailand PCL;5998234.6692']
# row #96['AkademikerPension;company_name: Ulker Biskuvi Sanayi AS;284129.380039602']
# row #97['AkademikerPension;company_name: Uni-President Enterprises Corp;1021750.49721792']
# row #98['AkademikerPension;company_name: Teco Electric and Machinery Co Ltd;811915.49778927']
# row #99['AkademikerPension;company_name: King Slide Works Co Ltd;977659.747337973']
# row #100['AkademikerPension;company_name: Delta Electronics Inc;27164056.777765']
# row #101['AkademikerPension;company_name: Hon Hai Precision Industry Co Ltd;16106761.3561436']
# row #102['AkademikerPension;company_name: Taiwan Semiconductor Manufacturing Co Ltd;410579516.634966']
# row #103['AkademikerPension;company_name: Chroma ATE Inc;25907312.2674912']
# row #104['AkademikerPension;company_name: Realtek Semiconductor Corp;15287199.13591']
# row #105['AkademikerPension;company_name: MediaTek Inc;80986248.1805111']
# row #106['AkademikerPension;company_name: Sinbon Electronics Co Ltd;4865037.8567532']
# row #107['AkademikerPension;company_name: eMemory Technology Inc;4151522.478696']
# row #108['AkademikerPension;company_name: RichWave Technology Corp;14610538.5502176']
# row #109['AkademikerPension;company_name: ASPEED Technology Inc;6359497.812684']
# row #110['AkademikerPension;company_name: KMC Kuei Meng International Inc;3728437.379848']
# row #111['AkademikerPension;company_name: Poya International Co Ltd;3786611.5796896']
# row #112['AkademikerPension;company_name: Voltronic Power Technology Corp;4003733.56909841']
# row #113['AkademikerPension;company_name: PChome Online Inc;753284.057948916']
# row #114['AkademikerPension;company_name: Merida Industry Co Ltd;1687440.29540534']
# row #115['AkademikerPension;company_name: Giant Manufacturing Co Ltd;2371582.55354252']
# row #116['AkademikerPension;company_name: AAR Corp;548052.5']
# row #117['AkademikerPension;company_name: AFLAC INC;3602097.1285445']
# row #118['AkademikerPension;company_name: AGCO CORP;8312229.87982']
# row #119['AkademikerPension;company_name: AES Corp/The;19715136.4936877']
# row #120['AkademikerPension;company_name: ALX Oncology Holdings Inc;1155669.5']
# row #121['AkademikerPension;company_name: AT&T Inc;68791559.4558']
# row #122['AkademikerPension;company_name: AZZ Inc;873962.61']
# row #123['AkademikerPension;company_name: AbbVie Inc;81218194.0187519']
# row #124['AkademikerPension;company_name: ABIOMED Inc;2196748.02']
# row #125['AkademikerPension;company_name: Acadia Realty Trust;2846448.32']
# row #126['AkademikerPension;company_name: Accolade Inc;1701182.8']
# row #127['AkademikerPension;company_name: Activision Blizzard Inc;100044553.948866']
# row #128['AkademikerPension;company_name: ADAPTHEALTH CORP;1883538.753938']
# row #129['AkademikerPension;company_name: Adobe Inc;201117116.11475']
# row #130['AkademikerPension;company_name: Advanced Micro Devices Inc;80078460.0611797']
# row #131['AkademikerPension;company_name: AeroVironment Inc;268750.14']
# row #132['AkademikerPension;company_name: Agilent Technologies Inc;33698210.2894287']
# row #133['AkademikerPension;company_name: Agree Realty Corp;6591112.8923055']
# row #134['AkademikerPension;company_name: Akero Therapeutics Inc;658664.75']
# row #135['AkademikerPension;company_name: Chassix Inc;1311394.40666493']
# row #136['AkademikerPension;company_name: Alamo Group Inc;8302018.43']
# row #137['AkademikerPension;company_name: Albany International Corp;521227.61']
# row #138['AkademikerPension;company_name: Alexandria Real Estate Equities Inc;73974606.742304']
# row #139['AkademikerPension;company_name: Align Technology Inc;2911370.74']
# row #140['AkademikerPension;company_name: Aligos Therapeutics Inc;305266.76']
# row #141['AkademikerPension;company_name: Allakos Inc;957668.5']
# row #142['AkademikerPension;company_name: Alleghany Corp;3810612.334298']
# row #143['AkademikerPension;company_name: Allegheny Technologies Inc;1060378.75']
# row #144['AkademikerPension;company_name: Allegiant Travel Co;8581218.78']
# row #145['AkademikerPension;company_name: ALLETE Inc;2161796.725452']
# row #146['AkademikerPension;company_name: Allscripts Healthcare Solutions Inc;1942695.62']
# row #147['AkademikerPension;company_name: Alpha Metallurgical Resources Inc;259735.88']
# row #148['AkademikerPension;company_name: Alphabet Inc;415817388.264308']
# row #149['AkademikerPension;company_name: Alphabet Inc;657932222.643876']
# row #150['AkademikerPension;company_name: Altice USA Inc;45513404.318785']
# row #151['AkademikerPension;company_name: Altra Industrial Motion Corp;480705.55']
# row #152['AkademikerPension;company_name: Amazon.com Inc;543903904.608084']
# row #153['AkademikerPension;company_name: AMERANT BANCORP INC;2302864.600025']
# row #154['AkademikerPension;company_name: American Eagle Outfitters Inc;3574165.74']
# row #155['AkademikerPension;company_name: American Express Co;10300494.674329']
# row #156['AkademikerPension;company_name: American Tower Corp;227761504.583751']
# row #157['AkademikerPension;company_name: American Vanguard Corp;1139349.61']
# row #158['AkademikerPension;company_name: AMERICAN WATER WORKS CO INC;17039589.95475']
# row #159['AkademikerPension;company_name: American Woodmark Corp;197745.03']
# row #160['AkademikerPension;company_name: AMERISAFE Inc;6792272.43080393']
# row #161['AkademikerPension;company_name: AMERISOURCEBERGEN CORP;85102663.6500901']
# row #162['AkademikerPension;company_name: Ameriprise Financial Inc;97538322.0132058']
# row #163['AkademikerPension;company_name: Ameris Bancorp;12843276.2093883']
# row #164['AkademikerPension;company_name: Amgen Inc;31675161.2168871']
# row #165['AkademikerPension;company_name: Amicus Therapeutics Inc;1036550.01']
# row #166['AkademikerPension;company_name: Analog Devices Inc;54035911.3262651']
# row #167['AkademikerPension;company_name: ANSYS Inc;18587387.3335']
# row #168['AkademikerPension;company_name: Anthem Inc;88520997.8988303']
# row #169['AkademikerPension;company_name: Apellis Pharmaceuticals Inc;2621019.55']
# row #170['AkademikerPension;company_name: Apple Inc;533791197.881818']
# row #171['AkademikerPension;company_name: APPLIED MATERIALS INC;166507582.318083']
# row #172['AkademikerPension;company_name: Apria Inc;1606648.83']
# row #173['AkademikerPension;company_name: Archer-Daniels-Midland Co;24438646.5461189']
# row #174['AkademikerPension;company_name: Arena Pharmaceuticals Inc;1309229.8']
# row #175['AkademikerPension;company_name: Arista Networks Inc;29357236.0196021']
# row #176['AkademikerPension;company_name: Array Technologies Inc;16674421.6565348']
# row #177['AkademikerPension;company_name: Arrowhead Pharmaceuticals Inc;254815.99']
# row #178['AkademikerPension;company_name: Artisan Partners Asset Management Inc;1992007.24']
# row #179['AkademikerPension;company_name: Arvinas Inc;309731.65']
# row #180['AkademikerPension;company_name: Asana Inc;1128274.93']
# row #181['AkademikerPension;company_name: Aspen Technology Inc;9833010.51']
# row #182['AkademikerPension;company_name: ATD New Holdings Inc;10363020.071625']
# row #183['AkademikerPension;company_name: Atlantic Capital Bancshares Inc;540526.07']
# row #184['AkademikerPension;company_name: ATLANTIC UNION BANKSHARES CO;25671.022272']
# row #185['AkademikerPension;company_name: Atlantic Union Bankshares Corp;3719384.01']
# row #186['AkademikerPension;company_name: AtriCure Inc;11991900.5711623']
# row #187['AkademikerPension;company_name: Atreca Inc;114071.01']
# row #188['AkademikerPension;company_name: Autodesk Inc;10473226.58']
# row #189['AkademikerPension;company_name: AUTOLIV INC;31912827.2099332']
# row #190['AkademikerPension;company_name: Automatic Data Processing Inc;3426899.71']
# row #191['AkademikerPension;company_name: AutoZone Inc;10318870.63']
# row #192['AkademikerPension;company_name: Avanos Medical Inc;1196214.55']
# row #193['AkademikerPension;company_name: Aveanna Healthcare Holdings Inc;1517087.73']
# row #194['AkademikerPension;company_name: Avient Corp;16594897.2836972']
# row #195['AkademikerPension;company_name: Avidity Biosciences Inc;308169.3']
# row #196['AkademikerPension;company_name: Axcelis Technologies Inc;1694464.61']
# row #197['AkademikerPension;company_name: Balchem Corp;8406941.05']
# row #198['AkademikerPension;company_name: Bandwidth Inc;2084542.59']
# row #199['AkademikerPension;company_name: BANC OF CALIFORNIA INC;1704582.3728']
# row #200['AkademikerPension;company_name: Bank of America Corp;109789854.299653']
# row #201['AkademikerPension;company_name: Bank of New York Mellon Corp/The;41996070.3980261']
# row #202['AkademikerPension;company_name: Baxter International Inc;39497983.7']
# row #203['AkademikerPension;company_name: Becton Dickinson and Co;149239005.75152']
# row #204['AkademikerPension;company_name: Bed Bath & Beyond Inc;34230777.4981328']
# row #205['AkademikerPension;company_name: BellRing Brands Inc;517445.41']
# row #206['AkademikerPension;company_name: Berkshire Hathaway Inc;249480816.354943']
# row #207['AkademikerPension;company_name: Best Buy Co Inc;10255518.89']
# row #208['AkademikerPension;company_name: Bio-Rad Laboratories Inc;17511147.72']
# row #209['AkademikerPension;company_name: Biogen Inc;12995387.85']
# row #210['AkademikerPension;company_name: BioAtla Inc;500697.35']
# row #211['AkademikerPension;company_name: Black Diamond Therapeutics Inc;49960.0000000001']
# row #212['AkademikerPension;company_name: Blackstone Group Inc/The;46308110.1686811']
# row #213["AkademikerPension;company_name: Bloomin' Brands Inc;3265000.3"]
# row #214['AkademikerPension;company_name: Blueprint Medicines Corp;996885.4']
# row #215['AkademikerPension;company_name: BOISE CASCADE CO;1464566.748685']
# row #216['AkademikerPension;company_name: Bolt Biotherapeutics Inc;21302.4900000002']
# row #217['AkademikerPension;company_name: Booking Holdings Inc;242429242.676657']
# row #218['AkademikerPension;company_name: Boot Barn Holdings Inc;11035603.4']
# row #219['AkademikerPension;company_name: BorgWarner Inc;10349038.7796915']
# row #220['AkademikerPension;company_name: Boston Scientific Corp;163233219.922993']
# row #221['AkademikerPension;company_name: Boyd Gaming Corp;2901965.64']
# row #222['AkademikerPension;company_name: Bright Horizons Family Solutions Inc;31707991.0819377']
# row #223['AkademikerPension;company_name: Bristol-Myers Squibb Co;105027980.615922']
# row #224['AkademikerPension;company_name: Broadcom Inc;64075783.0329627']
# row #225['AkademikerPension;company_name: Brooks Automation Inc;15243271.34']
# row #226['AkademikerPension;company_name: Builders FirstSource Inc;6306002.65']
# row #227['AkademikerPension;company_name: Burlington Stores Inc;13771271.83']
# row #228['AkademikerPension;company_name: CH Robinson Worldwide Inc;29137757.5519002']
# row #229['AkademikerPension;company_name: Cigna Corp;68758404.3028281']
# row #230['AkademikerPension;company_name: CIT Group Inc;29434034.7028923']
# row #231['AkademikerPension;company_name: CME Group Inc;205810042.222809']
# row #232['AkademikerPension;company_name: CNO Financial Group Inc;1383465.27']
# row #233['AkademikerPension;company_name: CVS Health Corp;51810951.2550335']
# row #234['AkademikerPension;company_name: Cadence Design Systems Inc;73039928.3388999']
# row #235['AkademikerPension;company_name: Caesars Entertainment Inc;5211909.88']
# row #236['AkademikerPension;company_name: CALIFORNIA RESOURCES CORP;784520.981316']
# row #237['AkademikerPension;company_name: California Resources Corp;10077642.000486']
# row #238['AkademikerPension;company_name: Cardiovascular Systems Inc;2690955.47']
# row #239['AkademikerPension;company_name: Cardlytics Inc;3575042.723118']
# row #240['AkademikerPension;company_name: Cargurus Inc;2314331.57']
# row #241['AkademikerPension;company_name: CarMax Inc;98312797.8418845']
# row #242['AkademikerPension;company_name: Carrier Global Corp;70925566.3625858']
# row #243['AkademikerPension;company_name: Castle Biosciences Inc;2957968.38']
# row #244['AkademikerPension;company_name: CATHAY GENERAL BANCORP;9153085.7291075']
# row #245['AkademikerPension;company_name: Cavco Industries Inc;4068880.45']
# row #246['AkademikerPension;company_name: Celanese Corp;17464477.02']
# row #247['AkademikerPension;company_name: Celldex Therapeutics Inc;446808.49']
# row #248['AkademikerPension;company_name: Celsius Holdings Inc;2614919.45']
# row #249['AkademikerPension;company_name: Centene Corp;63541226.6786357']
# row #250['AkademikerPension;company_name: Central Garden & Pet Co;10319309.21']
# row #251['AkademikerPension;company_name: Century Communities Inc;5149801.99']
# row #252['AkademikerPension;company_name: Cerence Inc;6811536.74']
# row #253['AkademikerPension;company_name: Cerner Corp;6977928.51145349']
# row #254['AkademikerPension;company_name: Chart Industries Inc;7652368.13']
# row #255['AkademikerPension;company_name: Charter Communications Inc;73089111.8107477']
# row #256["AkademikerPension;company_name: Chefs' Warehouse Inc/The;4442215.12"]
# row #257['AkademikerPension;company_name: ChemoCentryx Inc;301918.1']
# row #258['AkademikerPension;company_name: Chipotle Mexican Grill Inc;26681157.31']
# row #259['AkademikerPension;company_name: Churchill Downs Inc;6225226.37']
# row #260["AkademikerPension;company_name: Chuy's Holdings Inc;4597741.49"]
# row #261['AkademikerPension;company_name: Ciena Corp;42426142.2544273']
# row #262['AkademikerPension;company_name: Cinemark Holdings Inc;3109524.6']
# row #263['AkademikerPension;company_name: Cisco Systems Inc/Delaware;106274233.332871']
# row #264['AkademikerPension;company_name: Citigroup Inc;73754447.5571281']
# row #265['AkademikerPension;company_name: Citizens Financial Group Inc;68696432.9455459']
# row #266['AkademikerPension;company_name: Clean Harbors Inc;6712622.31']
# row #267['AkademikerPension;company_name: Clean Energy Fuels Corp;380357.13']
# row #268['AkademikerPension;company_name: Clear Channel Outdoor Holdings Inc;183697.678929112']
# row #269['AkademikerPension;company_name: Cleveland-Cliffs Inc;893316.98']
# row #270['AkademikerPension;company_name: Coca-Cola Co/The;5331959.19828976']
# row #271['AkademikerPension;company_name: Cognex Corp;9424162.3615']
# row #272['AkademikerPension;company_name: Cognizant Technology Solutions Corp;10851781.6997971']
# row #273['AkademikerPension;company_name: Coherent Inc;674121.16']
# row #274['AkademikerPension;company_name: Cohen & Steers Inc;7929382.33']
# row #275['AkademikerPension;company_name: Cohu Inc;837933.78']
# row #276['AkademikerPension;company_name: Colgate-Palmolive Co;3013439.54']
# row #277['AkademikerPension;company_name: Colony Capital Inc;1316589.74']
# row #278['AkademikerPension;company_name: Comcast Corp;220462961.402039']
# row #279['AkademikerPension;company_name: Comerica Inc;2799792.1105082']
# row #280['AkademikerPension;company_name: Compass Minerals International Inc;4683558.23']
# row #281['AkademikerPension;company_name: Conagra Brands Inc;20312037.4873519']
# row #282['AkademikerPension;company_name: Constellation Pharmaceuticals Inc;447187.52']
# row #283['AkademikerPension;company_name: Cooper Cos Inc/The;41401637.7282384']
# row #284['AkademikerPension;company_name: CORTEVA INC;5978745.19604371']
# row #285['AkademikerPension;company_name: Costco Wholesale Corp;117451924.036935']
# row #286['AkademikerPension;company_name: Covetrus Inc;10666795.66']
# row #287['AkademikerPension;company_name: Crinetics Pharmaceuticals Inc;433001.41']
# row #288['AkademikerPension;company_name: Crocs Inc;4039280.51']
# row #289['AkademikerPension;company_name: Crown Castle International Corp;32479314.6981377']
# row #290['AkademikerPension;company_name: CryoLife Inc;7405654.71290425']
# row #291['AkademikerPension;company_name: CryoPort Inc;6520159.35']
# row #292['AkademikerPension;company_name: Cullinan Oncology Inc;217015.32']
# row #293['AkademikerPension;company_name: CUMMINS INC;67025383.8440259']
# row #294['AkademikerPension;company_name: Cytokinetics Inc;475391.06']
# row #295['AkademikerPension;company_name: DR Horton Inc;25252005.9955315']
# row #296['AkademikerPension;company_name: Danaher Corp;257156218.766479']
# row #297['AkademikerPension;company_name: Darling Ingredients Inc;54852097.2879781']
# row #298['AkademikerPension;company_name: Daseke Inc;917188.66']
# row #299['AkademikerPension;company_name: Deciphera Pharmaceuticals Inc;409861.75']
# row #300['AkademikerPension;company_name: Deckers Outdoor Corp;3883004.42']
# row #301['AkademikerPension;company_name: Deere & Co;203993001.507748']
# row #302['AkademikerPension;company_name: Dell Technologies Inc;52793197.1501056']
# row #303['AkademikerPension;company_name: Design Therapeutics Inc;414370.55']
# row #304['AkademikerPension;company_name: Dexcom Inc;29392646.195938']
# row #305['AkademikerPension;company_name: Diamond Offshore Drilling Inc;38327.2323689336']
# row #306['AkademikerPension;company_name: Dicerna Pharmaceuticals Inc;990529.33']
# row #307['AkademikerPension;company_name: Digital Realty Trust Inc;73422049.3405127']
# row #308['AkademikerPension;company_name: Digital Turbine Inc;780062.06']
# row #309['AkademikerPension;company_name: Walt Disney Co/The;52301605.2583149']
# row #310['AkademikerPension;company_name: Discovery Inc;942436.01']
# row #311['AkademikerPension;company_name: Dolby Laboratories Inc;3784858.09']
# row #312['AkademikerPension;company_name: Dollar General Corp;345686.75']
# row #313['AkademikerPension;company_name: DOLLAR TREE INC;73332948.5073559']
# row #314['AkademikerPension;company_name: DUKE ENERGY CORP;26034819.5349409']
# row #315['AkademikerPension;company_name: Dycom Industries Inc;5690302.39']
# row #316['AkademikerPension;company_name: Eastern Bankshares Inc;3486026.72']
# row #317['AkademikerPension;company_name: Eastman Chemical Co;8020152.83696247']
# row #318['AkademikerPension;company_name: eBay Inc;95301304.1193964']
# row #319['AkademikerPension;company_name: Ecolab Inc;111804403.703961']
# row #320['AkademikerPension;company_name: Edwards Lifesciences Corp;93926100.3473886']
# row #321['AkademikerPension;company_name: 89bio Inc;447454.5']
# row #322['AkademikerPension;company_name: 8x8 Inc;1203902.18']
# row #323['AkademikerPension;company_name: Electronic Arts Inc;20637803.37']
# row #324['AkademikerPension;company_name: ELEMENT SOLUTIONS INC;1426594.424977']
# row #325['AkademikerPension;company_name: Emergent BioSolutions Inc;4880218.18']
# row #326['AkademikerPension;company_name: EMERSON ELECTRIC CO;8868887.10319799']
# row #327['AkademikerPension;company_name: Enphase Energy Inc;794461.56']
# row #328['AkademikerPension;company_name: EQUINIX INC;14396444.7696']
# row #329['AkademikerPension;company_name: EQUITABLE HOLDINGS INC;42310309.1514015']
# row #330['AkademikerPension;company_name: Essential Properties Realty Trust Inc;5420112.84']
# row #331['AkademikerPension;company_name: Etsy Inc;1608281.19']
# row #332['AkademikerPension;company_name: Eventbrite Inc;2317298.59']
# row #333['AkademikerPension;company_name: Evercore Inc;1702650.19']
# row #334['AkademikerPension;company_name: EVERCORE INC - A;7937.763114']
# row #335['AkademikerPension;company_name: Exelon Corp;70896865.7784309']
# row #336['AkademikerPension;company_name: ExlService Holdings Inc;3691638.82']
# row #337['AkademikerPension;company_name: Expeditors International of Washington Inc;4288450.61']
# row #338['AkademikerPension;company_name: EXPEDITORS INTL WASH INC;19789.174599']
# row #339['AkademikerPension;company_name: Flywire Corp;20888.8499999999']
# row #340['AkademikerPension;company_name: FTI Consulting Inc;9860624.67']
# row #341['AkademikerPension;company_name: Facebook Inc;280556929.827158']
# row #342['AkademikerPension;company_name: Fate Therapeutics Inc;394663.01']
# row #343['AkademikerPension;company_name: Fastenal Co;17258078.6481913']
# row #344['AkademikerPension;company_name: FedEx Corp;160881338.058621']
# row #345['AkademikerPension;company_name: Ferrellgas Partners LP;878060.112990238']
# row #346['AkademikerPension;company_name: Ferro Corp;1323246.01']
# row #347['AkademikerPension;company_name: Fidelity National Information Services Inc;137182693.088714']
# row #348['AkademikerPension;company_name: Fifth Third Bancorp;13694981.12']
# row #349['AkademikerPension;company_name: Fintech Acquisition Corp IV;1403201.89']
# row #350['AkademikerPension;company_name: First Citizens BancShares Inc/NC;30102914.8466077']
# row #351['AkademikerPension;company_name: First Interstate BancSystem Inc;2039775.43']
# row #352['AkademikerPension;company_name: First Republic Bank/CA;108365123.734145']
# row #353['AkademikerPension;company_name: First Solar Inc;22563031.8462261']
# row #354['AkademikerPension;company_name: Fiserv Inc;199797604.521833']
# row #355['AkademikerPension;company_name: Five Below Inc;7563311.07']
# row #356['AkademikerPension;company_name: Five Star Bancorp;560787.16']
# row #357['AkademikerPension;company_name: Five Point Holdings LLC;729242.05']
# row #358['AkademikerPension;company_name: Forma Therapeutics Holdings Inc;127378.31']
# row #359['AkademikerPension;company_name: FormFactor Inc;4149527.774888']
# row #360['AkademikerPension;company_name: Fortinet Inc;5349376.4']
# row #361['AkademikerPension;company_name: Fortive Corp;52481067.3460788']
# row #362['AkademikerPension;company_name: Fox Factory Holding Corp;2611290.48']
# row #363['AkademikerPension;company_name: Franklin Resources Inc;12904917.3674652']
# row #364['AkademikerPension;company_name: Freeport-McMoRan Inc;17277552.77']
# row #365['AkademikerPension;company_name: Freshpet Inc;5039126.12']
# row #366['AkademikerPension;company_name: Frontier Communications Parent Inc;12252610.4488813']
# row #367['AkademikerPension;company_name: FuelCell Energy Inc;378179.56']
# row #368['AkademikerPension;company_name: HB Fuller Co;1615802.82']
# row #369['AkademikerPension;company_name: Generac Holdings Inc;8704203.62']
# row #370['AkademikerPension;company_name: General Mills Inc;15573337.92']
# row #371['AkademikerPension;company_name: General Motors Co;4617980.99']
# row #372['AkademikerPension;company_name: Gilead Sciences Inc;84384890.7885233']
# row #373['AkademikerPension;company_name: Glacier Bancorp Inc;11172082.84']
# row #374['AkademikerPension;company_name: Glaukos Corp;2991647.85']
# row #375['AkademikerPension;company_name: Global Blood Therapeutics Inc;248728.91']
# row #376['AkademikerPension;company_name: Global Payments Inc;60817681.0563532']
# row #377['AkademikerPension;company_name: Global Partners LP/MA;3100869.33091664']
# row #378['AkademikerPension;company_name: Globus Medical Inc;15644243.1369053']
# row #379['AkademikerPension;company_name: GOLDMAN SACHS GROUP INC;98840.3338125']
# row #380['AkademikerPension;company_name: Goldman Sachs Group Inc/The;29416464.79']
# row #381['AkademikerPension;company_name: WW Grainger Inc;59842264.3896307']
# row #382['AkademikerPension;company_name: Grand Canyon Education Inc;10040833.22']
# row #383['AkademikerPension;company_name: Green Plains Inc;2149162.87']
# row #384['AkademikerPension;company_name: Greenbrier Cos Inc/The;2533678.79']
# row #385['AkademikerPension;company_name: HCA Healthcare Inc;107459762.891622']
# row #386['AkademikerPension;company_name: HP Inc;27503754.1043372']
# row #387['AkademikerPension;company_name: Hain Celestial Group Inc/The;461018.45933271']
# row #388['AkademikerPension;company_name: Halozyme Therapeutics Inc;8018593.70745071']
# row #389['AkademikerPension;company_name: Hamilton Lane Inc;2302211.41']
# row #390['AkademikerPension;company_name: Hamilton Lane Alliance Holdings I Inc;942250.17']
# row #391['AkademikerPension;company_name: Hannon Armstrong Sustainable Infrastructure Capita;10573231.8037471']
# row #392['AkademikerPension;company_name: Hanover Insurance Group Inc/The;1027546.45']
# row #393['AkademikerPension;company_name: Hartford Financial Services Group Inc/The;5242901.6']
# row #394['AkademikerPension;company_name: HARTFORD FINANCIAL SVCS GRP;28079.8096425']
# row #395['AkademikerPension;company_name: HAWAIIAN ELECTRIC INDS;49516.916226']
# row #396['AkademikerPension;company_name: Hawaiian Electric Industries Inc;6269715.42']
# row #397['AkademikerPension;company_name: HEALTHCARE SERVICES GROUP;27546.517416']
# row #398['AkademikerPension;company_name: Healthcare Services Group Inc;3981301.48']
# row #399['AkademikerPension;company_name: Health Catalyst Inc;1599981.98']
# row #400['AkademikerPension;company_name: HealthEquity Inc;9412019.58']
# row #401['AkademikerPension;company_name: Heartland Express Inc;4793035.82']
# row #402['AkademikerPension;company_name: Hecla Mining Co;1380570.2138825']
# row #403['AkademikerPension;company_name: Helios Technologies Inc;10900660.6838358']
# row #404['AkademikerPension;company_name: HERSHEY CO/THE;9457626.6146015']
# row #405['AkademikerPension;company_name: Hexcel Corp;8092139.75']
# row #406['AkademikerPension;company_name: Hexion Holdings Corp;12200893.6148068']
# row #407['AkademikerPension;company_name: HOME BANCSHARES INC;25740.854538']
# row #408['AkademikerPension;company_name: Home BancShares Inc/AR;5030498.43']
# row #409['AkademikerPension;company_name: Home Depot Inc/The;215009917.926137']
# row #410['AkademikerPension;company_name: Horace Mann Educators Corp;8093984.47505029']
# row #411['AkademikerPension;company_name: Houghton Mifflin Harcourt Co;3123113.54']
# row #412['AkademikerPension;company_name: Houlihan Lokey Inc;8011795.23']
# row #413['AkademikerPension;company_name: Hub Group Inc;615743.57']
# row #414['AkademikerPension;company_name: Humana Inc;7031681.55']
# row #415['AkademikerPension;company_name: Huron Consulting Group Inc;2163188.26']
# row #416['AkademikerPension;company_name: Hydrofarm Holdings Group Inc;2063906.19']
# row #417['AkademikerPension;company_name: ICF International Inc;7684583.44']
# row #418['AkademikerPension;company_name: ICU Medical Inc;4134775.89']
# row #419['AkademikerPension;company_name: iRhythm Technologies Inc;1001121.33']
# row #420['AkademikerPension;company_name: IDACORP Inc;6873447.4787085']
# row #421['AkademikerPension;company_name: IDEX Corp;11660284.83']
# row #422['AkademikerPension;company_name: iHeartMedia Inc;410964.981841295']
# row #423['AkademikerPension;company_name: iHeartMedia Inc;248223.568749156']
# row #424['AkademikerPension;company_name: ImmunoGen Inc;978160.26']
# row #425['AkademikerPension;company_name: Inari Medical Inc;2487475.5']
# row #426['AkademikerPension;company_name: Independence Realty Trust Inc;2763758.99758337']
# row #427['AkademikerPension;company_name: Ingersoll Rand Inc;11869652.79']
# row #428['AkademikerPension;company_name: Ingevity Corp;3145319.59']
# row #429['AkademikerPension;company_name: Inhibrx Inc;241727.19']
# row #430['AkademikerPension;company_name: Installed Building Products Inc;17415140.4332143']
# row #431['AkademikerPension;company_name: Innovative Industrial Properties Inc;2445912.41']
# row #432['AkademikerPension;company_name: Instil Bio Inc;311836.35']
# row #433['AkademikerPension;company_name: Inozyme Pharma Inc;330098.09']
# row #434['AkademikerPension;company_name: Integra LifeSciences Holdings Corp;8764297.94']
# row #435['AkademikerPension;company_name: Intel Corp;116923912.528876']
# row #436['AkademikerPension;company_name: Intellia Therapeutics Inc;498250.91']
# row #437['AkademikerPension;company_name: Inter Parfums Inc;2070712.1']
# row #438['AkademikerPension;company_name: Intercontinental Exchange Inc;77734169.2749528']
# row #439['AkademikerPension;company_name: International Bancshares Corp;1429872.83']
# row #440['AkademikerPension;company_name: International Business Machines Corp;72849401.3490074']
# row #441['AkademikerPension;company_name: INTL BUSINESS MACHINES CORP;829769.223964734']
# row #442['AkademikerPension;company_name: International Flavors & Fragrances Inc;30432957.1374007']
# row #443['AkademikerPension;company_name: International Paper Co;13761161.790018']
# row #444['AkademikerPension;company_name: Interpublic Group of Cos Inc/The;26179132.0203359']
# row #445['AkademikerPension;company_name: Intuit Inc;46179311.4552174']
# row #446['AkademikerPension;company_name: Iovance Biotherapeutics Inc;122449.05']
# row #447['AkademikerPension;company_name: Itron Inc;10322188.2961332']
# row #448['AkademikerPension;company_name: JPMorgan Chase & Co;205154535.743732']
# row #449['AkademikerPension;company_name: JELD-WEN Holding Inc;5809554.85567']
# row #450['AkademikerPension;company_name: JetBlue Airways Corp;2166576.47']
# row #451['AkademikerPension;company_name: Johnson & Johnson;124514738.000636']
# row #452['AkademikerPension;company_name: J2 Global Inc;1297614.22']
# row #453['AkademikerPension;company_name: KAR Auction Services Inc;6156026.55']
# row #454['AkademikerPension;company_name: KKR & CO INC;63327180.1392314']
# row #455['AkademikerPension;company_name: KalVista Pharmaceuticals Inc;1082010.81']
# row #456['AkademikerPension;company_name: Kansas City Southern;84531420.5397742']
# row #457['AkademikerPension;company_name: Karuna Therapeutics Inc;772021.86']
# row #458['AkademikerPension;company_name: Kennametal Inc;1471249.54']
# row #459['AkademikerPension;company_name: Keysight Technologies Inc;13251183.4413']
# row #460['AkademikerPension;company_name: Kimberly-Clark Corp;4559505.22']
# row #461['AkademikerPension;company_name: Kinder Morgan Inc;37728436.2798103']
# row #462['AkademikerPension;company_name: Kodiak Sciences Inc;1076825.34']
# row #463['AkademikerPension;company_name: Kraft Heinz Co/The;15162393.83834']
# row #464['AkademikerPension;company_name: Kratos Defense & Security Solutions Inc;357211.99']
# row #465['AkademikerPension;company_name: KROGER CO;125001.878191585']
# row #466['AkademikerPension;company_name: Kroger Co/The;25737314.0246363']
# row #467['AkademikerPension;company_name: Kura Oncology Inc;535562.69']
# row #468['AkademikerPension;company_name: Kymera Therapeutics Inc;585058.13']
# row #469['AkademikerPension;company_name: LHC Group Inc;10277530.6']
# row #470['AkademikerPension;company_name: LKQ Corp;6013750.3608']
# row #471['AkademikerPension;company_name: Lattice Semiconductor Corp;4723533.79']
# row #472['AkademikerPension;company_name: Liberty Media Corp-Liberty Braves;3482262.89']
# row #473['AkademikerPension;company_name: Lindblad Expeditions Holdings Inc;1141438.19']
# row #474['AkademikerPension;company_name: Lithia Motors Inc;13851018.94']
# row #475['AkademikerPension;company_name: Livent Corp;2094910.31']
# row #476['AkademikerPension;company_name: LiveRamp Holdings Inc;681198.91']
# row #477['AkademikerPension;company_name: Loews Corp;4516663.127277']
# row #478['AkademikerPension;company_name: Louisiana-Pacific Corp;2290009.013936']
# row #479["AkademikerPension;company_name: Lowe's Cos Inc;180011400.736282"]
# row #480['AkademikerPension;company_name: Lululemon Athletica Inc;17827204.8857546']
# row #481['AkademikerPension;company_name: M & T BANK CORP;27674.98932']
# row #482['AkademikerPension;company_name: M&T Bank Corp;4042812.76']
# row #483['AkademikerPension;company_name: MGIC Investment Corp;4630166.35']
# row #484['AkademikerPension;company_name: MACOM Technology Solutions Holdings Inc;11864735.0009311']
# row #485['AkademikerPension;company_name: Madrigal Pharmaceuticals Inc;691312.67']
# row #486['AkademikerPension;company_name: Marathon Petroleum Corp;82817349.1611662']
# row #487['AkademikerPension;company_name: Markel Corp;6209677.13']
# row #488['AkademikerPension;company_name: MarketAxess Holdings Inc;2500224.69']
# row #489['AkademikerPension;company_name: Marsh & McLennan Cos Inc;4649708.13']
# row #490['AkademikerPension;company_name: Marten Transport Ltd;768247.27']
# row #491['AkademikerPension;company_name: MasTec Inc;8851030.71']
# row #492['AkademikerPension;company_name: Mastercard Inc;277688635.20829']
# row #493['AkademikerPension;company_name: Maxim Integrated Products Inc;5198731.05']
# row #494['AkademikerPension;company_name: Maxar Technologies Inc;320848.85']
# row #495['AkademikerPension;company_name: Mayville Engineering Co Inc;1058951.57']
# row #496['AkademikerPension;company_name: McCormick & Co Inc/MD;10863121.41']
# row #497['AkademikerPension;company_name: Medallia Inc;1497003.59']
# row #498['AkademikerPension;company_name: Medpace Holdings Inc;11824708.31']
# row #499['AkademikerPension;company_name: MercadoLibre Inc;16030972.7288146']
# row #500['AkademikerPension;company_name: Merck & Co Inc;74361755.3157975']
# row #501['AkademikerPension;company_name: Meridian Bancorp Inc;4561058.26']
# row #502['AkademikerPension;company_name: MERITOR INC;3862712.3618685']
# row #503['AkademikerPension;company_name: Mersana Therapeutics Inc;603744.47']
# row #504['AkademikerPension;company_name: METLIFE INC;69133763.1995426']
# row #505['AkademikerPension;company_name: MetroMile Inc;567417.58']
# row #506['AkademikerPension;company_name: MICROSOFT CORP;1141040564.75873']
# row #507['AkademikerPension;company_name: Micron Technology Inc;124759375.227625']
# row #508['AkademikerPension;company_name: Middleby Corp/The;9377497.13']
# row #509['AkademikerPension;company_name: Minerals Technologies Inc;8397609.8']
# row #510['AkademikerPension;company_name: Mirati Therapeutics Inc;1761455.95']
# row #511['AkademikerPension;company_name: Mondelez International Inc;129007444.105726']
# row #512['AkademikerPension;company_name: Morgan Stanley;110558795.166496']
# row #513['AkademikerPension;company_name: NMI Holdings Inc;889648.1']
# row #514['AkademikerPension;company_name: NVR Inc;53771220.5144667']
# row #515['AkademikerPension;company_name: NOV Inc;4447640.78068934']
# row #516['AkademikerPension;company_name: NanoString Technologies Inc;2350311.18']
# row #517['AkademikerPension;company_name: National Health Investors Inc;5981834.34']
# row #518['AkademikerPension;company_name: National Storage Affiliates Trust;5171579.32']
# row #519['AkademikerPension;company_name: National Vision Holdings Inc;2574838.16']
# row #520['AkademikerPension;company_name: NeoGenomics Inc;4074699.22']
# row #521['AkademikerPension;company_name: Netflix Inc;49998225.1954102']
# row #522['AkademikerPension;company_name: Nevro Corp;2761102.1']
# row #523['AkademikerPension;company_name: New Jersey Resources Corp;2095800.13']
# row #524['AkademikerPension;company_name: Newmont Corp;35307175.5345086']
# row #525['AkademikerPension;company_name: NextEra Energy Inc;218012061.327337']
# row #526['AkademikerPension;company_name: NIKE Inc;74553228.5513428']
# row #527['AkademikerPension;company_name: NIKE INC -CL B;150038.23840712']
# row #528['AkademikerPension;company_name: Noble Finance Co;9894.49903772038']
# row #529['AkademikerPension;company_name: Norfolk Southern Corp;101340436.350058']
# row #530['AkademikerPension;company_name: NorthWestern Corp;8585448.34952501']
# row #531['AkademikerPension;company_name: NortonLifeLock Inc;2364978.09539507']
# row #532['AkademikerPension;company_name: Novavax Inc;1574132.78']
# row #533['AkademikerPension;company_name: Nucor Corp;15725677.0443587']
# row #534['AkademikerPension;company_name: NVIDIA Corp;162623813.14809']
# row #535['AkademikerPension;company_name: NuVasive Inc;3700111.28']
# row #536['AkademikerPension;company_name: Nurix Therapeutics Inc;422249.19']
# row #537['AkademikerPension;company_name: OceanFirst Financial Corp;7250169.38']
# row #538['AkademikerPension;company_name: Olema Pharmaceuticals Inc;257159.87']
# row #539["AkademikerPension;company_name: Ollie's Bargain Outlet Holdings Inc;7168896.24"]
# row #540['AkademikerPension;company_name: Olo Inc;102953.93']
# row #541['AkademikerPension;company_name: Omnicom Group Inc;2421767.41']
# row #542['AkademikerPension;company_name: Omnicell Inc;3065891.96']
# row #543['AkademikerPension;company_name: ON Semiconductor Corp;8639363.51']
# row #544['AkademikerPension;company_name: ONEOK Inc;22121964.3055224']
# row #545['AkademikerPension;company_name: Open Lending Corp;2356189.32']
# row #546['AkademikerPension;company_name: Oracle Corp;31119514.9942033']
# row #547['AkademikerPension;company_name: ORMAT TECHNOLOGIES INC;1006230.25158909']
# row #548['AkademikerPension;company_name: Otis Worldwide Corp;35325404.9835856']
# row #549['AkademikerPension;company_name: Otonomy Inc;96704.2500000003']
# row #550['AkademikerPension;company_name: Outfront Media Inc;4744780.56']
# row #551['AkademikerPension;company_name: Owens & Minor Inc;3400696.56']
# row #552['AkademikerPension;company_name: Owens Corning;38990589.2683753']
# row #553['AkademikerPension;company_name: Oxford Industries Inc;6950680.81382962']
# row #554['AkademikerPension;company_name: PGT Innovations Inc;3609290.64']
# row #555['AkademikerPension;company_name: PPG INDUSTRIES INC;3708829.84076935']
# row #556['AkademikerPension;company_name: PRA Group Inc;1349102.26']
# row #557['AkademikerPension;company_name: PS Business Parks Inc;5027902.71']
# row #558['AkademikerPension;company_name: PTC Therapeutics Inc;938310.61']
# row #559['AkademikerPension;company_name: PTC Inc;44808214.9355975']
# row #560['AkademikerPension;company_name: PACCAR INC;9725551.6793']
# row #561['AkademikerPension;company_name: Pacific Premier Bancorp Inc;11423016.69']
# row #562['AkademikerPension;company_name: Palomar Holdings Inc;4169235.68']
# row #563['AkademikerPension;company_name: Parker Drilling Co;295244.885309298']
# row #564['AkademikerPension;company_name: PARKER HANNIFIN CORP;34835.83806']
# row #565['AkademikerPension;company_name: Parker-Hannifin Corp;10422003.4']
# row #566['AkademikerPension;company_name: PATRICK INDUSTRIES INC;14574657.2393447']
# row #567['AkademikerPension;company_name: Paychex Inc;53291631.7484684']
# row #568['AkademikerPension;company_name: Paylocity Holding Corp;8426730.77']
# row #569['AkademikerPension;company_name: PayPal Holdings Inc;173505700.899586']
# row #570['AkademikerPension;company_name: Pebblebrook Hotel Trust;3909083.42']
# row #571['AkademikerPension;company_name: Penn National Gaming Inc;1027654.61']
# row #572['AkademikerPension;company_name: PennyMac Mortgage Investment Trust;1026415.08']
# row #573['AkademikerPension;company_name: PepsiCo Inc;24619782.18']
# row #574['AkademikerPension;company_name: Performance Food Group Co;17376199.3196738']
# row #575['AkademikerPension;company_name: Pfizer Inc;49077199.0781368']
# row #576['AkademikerPension;company_name: Phreesia Inc;7929326.06']
# row #577['AkademikerPension;company_name: Pinterest Inc;41385603.98']
# row #578['AkademikerPension;company_name: Portland General Electric Co;2353346.15']
# row #579['AkademikerPension;company_name: PotlatchDeltic Corp;2577270.49']
# row #580['AkademikerPension;company_name: Power Integrations Inc;8011975.104']
# row #581['AkademikerPension;company_name: T Rowe Price Group Inc;32975016.9861071']
# row #582['AkademikerPension;company_name: PriceSmart Inc;663348.74']
# row #583['AkademikerPension;company_name: Primoris Services Corp;8808934.09112453']
# row #584['AkademikerPension;company_name: ProAssurance Corp;1326561.22']
# row #585['AkademikerPension;company_name: Procter & Gamble Co/The;285995822.919337']
# row #586['AkademikerPension;company_name: Progressive Corp/The;20545395.5']
# row #587['AkademikerPension;company_name: Progyny Inc;10149780.43']
# row #588['AkademikerPension;company_name: Prologis Inc;25079917.2']
# row #589['AkademikerPension;company_name: ProSight Global Inc;377785.26']
# row #590['AkademikerPension;company_name: PRUDENTIAL FINANCIAL INC;19143250.6991266']
# row #591['AkademikerPension;company_name: Public Storage;69118142.429362']
# row #592['AkademikerPension;company_name: PulteGroup Inc;25249987.349135']
# row #593['AkademikerPension;company_name: Puma Biotechnology Inc;339807.27']
# row #594['AkademikerPension;company_name: QTS Realty Trust Inc;8220406.25151568']
# row #595['AkademikerPension;company_name: Q2 Holdings Inc;2232438.88']
# row #596['AkademikerPension;company_name: Quanta Services Inc;41247433.5074617']
# row #597['AkademikerPension;company_name: Radius Health Inc;193611.17']
# row #598['AkademikerPension;company_name: Radius Global Infrastructure Inc;1780795.78']
# row #599['AkademikerPension;company_name: Rambus Inc;2148229.07']
# row #600['AkademikerPension;company_name: Rapid7 Inc;12383746.907543']
# row #601['AkademikerPension;company_name: RAPT Therapeutics Inc;433092.05']
# row #602['AkademikerPension;company_name: Raymond James Financial Inc;7111248.55']
# row #603['AkademikerPension;company_name: Rayonier Inc;3938082.85']
# row #604['AkademikerPension;company_name: RBC Bearings Inc;9731503.96']
# row #605['AkademikerPension;company_name: Realty Income Corp;36875660.9501733']
# row #606['AkademikerPension;company_name: Reata Pharmaceuticals Inc;1001466.23']
# row #607['AkademikerPension;company_name: Red Rock Resorts Inc;1604417.6']
# row #608['AkademikerPension;company_name: Redfin Corp;1865761.69']
# row #609['AkademikerPension;company_name: Regal Beloit Corp;11247313.7205']
# row #610['AkademikerPension;company_name: Regeneron Pharmaceuticals Inc;43316889.2066652']
# row #611['AkademikerPension;company_name: Relay Therapeutics Inc;244230.44']
# row #612['AkademikerPension;company_name: Reliant Bancorp Inc;506088.67']
# row #613['AkademikerPension;company_name: Repay Holdings Corp;1987889.2']
# row #614['AkademikerPension;company_name: Republic Services Inc;22175517.1']
# row #615['AkademikerPension;company_name: REVOLUTION Medicines Inc;825284.53']
# row #616['AkademikerPension;company_name: Revolve Group Inc;3868465.68']
# row #617['AkademikerPension;company_name: Rocket Pharmaceuticals Inc;948271.08']
# row #618['AkademikerPension;company_name: Rogers Corp;24182411.9741744']
# row #619['AkademikerPension;company_name: Roper Technologies Inc;27680470.787']
# ...
# row #5294['Velliv;company_name: DAI-DAN CO LTD;111343']
# row #5295['Velliv;company_name: G-7 HOLDINGS INC;110611']
# row #5296['Velliv;company_name: KRONOS WORLDWIDE INC;110419']
# row #5297['Velliv;company_name: DIGITAL HOLDINGS INC;110380']
# row #5298['Velliv;company_name: TAKAMATSU CONSTRUCTION GROUP;110265']
# row #5299['Velliv;company_name: HIDAY HIDAKA CORP;109687']
# row #5300['Velliv;company_name: SHINNIHONSEIYAKU CO LTD;109340']
# row #5301['Velliv;company_name: YONEX CO LTD;109186']
# row #5302['Velliv;company_name: ANI PHARMACEUTICALS INC;109070']
# row #5303['Velliv;company_name: HIBIYA ENGINEERING LTD;108955']
# row #5304['Velliv;company_name: CENTRAL GARDEN & PET CO;108608']
# row #5305['Velliv;company_name: ARCLAND SERVICE HOLDINGS CO;108531']
# row #5306['Velliv;company_name: SCSK CORP;108412']
# row #5307['Velliv;company_name: RPA HOLDINGS INC;107606']
# row #5308['Velliv;company_name: MITSUBISHI RESEARCH INSTITUT;107568']
# row #5309['Velliv;company_name: TAMRON CO LTD;107336']
# row #5310['Velliv;company_name: APPLIED THERAPEUTICS INC;107298']
# row #5311['Velliv;company_name: MITSUBISHI ESTATE LOGISTICS;107221']
# row #5312['Velliv;company_name: RISO KYOIKU CO LTD;107144']
# row #5313['Velliv;company_name: IDOM INC;106990']
# row #5314['Velliv;company_name: LIFESTYLE INTL HLDGS LTD;106836']
# row #5315['Velliv;company_name: COLLECTOR AB;106760']
# row #5316['Velliv;company_name: ATHERSYS INC;106604']
# row #5317['Velliv;company_name: MAXEON SOLAR TECHNOLOGIE;106373']
# row #5318['Velliv;company_name: SHIN-ETSU POLYMER CO LTD;106296']
# row #5319['Velliv;company_name: KONISHI CO LTD;105641']
# row #5320['Velliv;company_name: FUJIBO HOLDINGS INC;105526']
# row #5321['Velliv;company_name: FUKUDA CORP;105140']
# row #5322['Velliv;company_name: UROGEN PHARMA LTD;104640']
# row #5323['Velliv;company_name: VIRNETX HOLDING CORP;104447']
# row #5324['Velliv;company_name: ONTRAK INC;104408']
# row #5325['Velliv;company_name: INAGEYA CO LTD;104370']
# row #5326['Velliv;company_name: VESTAS WIND SYSTEMS A/S;104287']
# row #5327['Velliv;company_name: PACK CORP/THE;104100']
# row #5328['Velliv;company_name: PERENTI GLOBAL LTD;103908']
# row #5329['Velliv;company_name: HLS THERAPEUTICS INC;103792']
# row #5330['Velliv;company_name: HENNGE KK;103753']
# row #5331['Velliv;company_name: DATAGROUP SE;103715']
# row #5332['Velliv;company_name: NUMIS CORPORATION PLC;103676']
# row #5333['Velliv;company_name: XBIOTECH INC;103137']
# row #5334['Velliv;company_name: MIZUNO CORP;103060']
# row #5335['Velliv;company_name: GMO GLOBALSIGN HOLDINGS KK;102636']
# row #5336['Velliv;company_name: JAPFA LTD;102559']
# row #5337['Velliv;company_name: ROGERS SUGAR INC;102521']
# row #5338['Velliv;company_name: CONCORDIA FINANCIAL GROUP LT;102367']
# row #5339['Velliv;company_name: ALTECH CORP;101365']
# row #5340['Velliv;company_name: NKARTA INC;101288']
# row #5341['Velliv;company_name: HOMOLOGY MEDICINES INC;100825']
# row #5342['Velliv;company_name: MOUNT GIBSON IRON LTD;100710']
# row #5343['Velliv;company_name: SOLGOLD PLC;100479']
# row #5344['Velliv;company_name: HUTCHISON TELECOMM HONG KONG;100170']
# row #5345['Velliv;company_name: YUASA TRADING CO LTD;98514']
# row #5346['Velliv;company_name: TOENEC CORP;98321']
# row #5347['Velliv;company_name: FRASERS HOSPITALITY TRUST;98321']
# row #5348['Velliv;company_name: FAR EAST HOSPITALITY TRUST;98206']
# row #5349['Velliv;company_name: HAWAIIAN HOLDINGS INC;97936']
# row #5350['Velliv;company_name: CUE BIOPHARMA INC;97396']
# row #5351['Velliv;company_name: ALPHA SYSTEMS INC;97358']
# row #5352['Velliv;company_name: KANTO DENKA KOGYO CO LTD;97281']
# row #5353['Velliv;company_name: JUPITER MINES LTD;97165']
# row #5354['Velliv;company_name: RISO KAGAKU CORP;96857']
# row #5355['Velliv;company_name: SANYO SPECIAL STEEL CO LTD;96703']
# row #5356['Velliv;company_name: BIODELIVERY SCIENCES INTL;96202']
# row #5357['Velliv;company_name: SILENCE THERAPEUTICS PLC;96202']
# row #5358['Velliv;company_name: MATSUYAFOODS HOLDINGS CO LTD;96125']
# row #5359['Velliv;company_name: MEISEI INDUSTRIAL CO LTD;95817']
# row #5360['Velliv;company_name: WORLD CO LTD;95740']
# row #5361['Velliv;company_name: MIROKU JYOHO SERVICE CO LTD;95701']
# row #5362['Velliv;company_name: JAPAN MEDICAL DYNAMIC MKT;95239']
# row #5363['Velliv;company_name: KOJIMA CO LTD;95200']
# row #5364['Velliv;company_name: COMPUTER MODELLING GROUP LTD;95200']
# row #5365['Velliv;company_name: PHATHOM PHARMACEUTICALS INC;94661']
# row #5366['Velliv;company_name: UNIPRES CORP;94622']
# row #5367['Velliv;company_name: ADVERUM BIOTECHNOLOGIES INC;94276']
# row #5368['Velliv;company_name: HOKUTO CORP;94199']
# row #5369['Velliv;company_name: TOSHO CO LTD;94083']
# row #5370['Velliv;company_name: NNIT A/S;93505']
# row #5371['Velliv;company_name: SHIKOKU CHEMICALS CORP;92889']
# row #5372['Velliv;company_name: NEOLEUKIN THERAPEUTICS INC;92850']
# row #5373['Velliv;company_name: NICHIREKI CO LTD;92658']
# row #5374['Velliv;company_name: SINKO INDUSTRIES LTD;92041']
# row #5375['Velliv;company_name: MITSUBISHI SHOKUHIN CO LTD;91926']
# row #5376['Velliv;company_name: PORR AG;91772']
# row #5377['Velliv;company_name: ONWARD HOLDINGS CO LTD;91617']
# row #5378['Velliv;company_name: HERITAGE INSURANCE HOLDINGS;91271']
# row #5379['Velliv;company_name: KEY COFFEE INC;91001']
# row #5380['Velliv;company_name: EM SYSTEMS CO LTD;90269']
# row #5381['Velliv;company_name: JDC CORP;90153']
# row #5382['Velliv;company_name: CITYCHAMP WATCH & JEWELLERY;90038']
# row #5383['Velliv;company_name: ZUMTOBEL GROUP AG;89807']
# row #5384['Velliv;company_name: TELEVISION BROADCASTS LTD;89421']
# row #5385['Velliv;company_name: VECTOR INC;89113']
# row #5386['Velliv;company_name: MITSUBISHI LOGISNEXT CO LTD;88728']
# row #5387['Velliv;company_name: DSP GROUP INC;88343']
# row #5388['Velliv;company_name: BAKKAVOR GROUP PLC;87649']
# row #5389['Velliv;company_name: UNION TOOL CO;87572']
# row #5390['Velliv;company_name: JAC RECRUITMENT CO LTD;87418']
# row #5391['Velliv;company_name: LEOPALACE21 CORP;87187']
# row #5392['Velliv;company_name: KYOEI STEEL LTD;86879']
# row #5393['Velliv;company_name: MELCO HOLDINGS INC;86725']
# row #5394['Velliv;company_name: ITOCHU-SHOKUHIN CO LTD;86532']
# row #5395['Velliv;company_name: AEON HOKKAIDO CORP;86493']
# row #5396['Velliv;company_name: LEC INC;86262']
# row #5397['Velliv;company_name: LANDEC CORP;86262']
# row #5398['Velliv;company_name: KYOKUTO KAIHATSU KOGYO CO;85992']
# row #5399['Velliv;company_name: MITSUBOSHI BELTING LTD;85915']
# row #5400['Velliv;company_name: DENYO CO LTD;84991']
# row #5401['Velliv;company_name: OILES CORP;84413']
# row #5402['Velliv;company_name: OCEAN YIELD ASA;84413']
# row #5403['Velliv;company_name: V-ZUG HOLDING AG;83912']
# row #5404['Velliv;company_name: WAKITA & CO LTD;83758']
# row #5405['Velliv;company_name: SB TECHNOLOGY CORP;83565']
# row #5406['Velliv;company_name: CMBC CAPITAL HOLDINGS LTD;83334']
# row #5407['Velliv;company_name: YONDOSHI HOLDINGS INC;82679']
# row #5408['Velliv;company_name: ACCELERATE DIAGNOSTICS INC;82024']
# row #5409['Velliv;company_name: J-OIL MILLS INC;81986']
# row #5410['Velliv;company_name: TSUKISHIMA KIKAI CO LTD;81947']
# row #5411['Velliv;company_name: MACAU LEGEND DEVELOPMENT LTD;81870']
# row #5412['Velliv;company_name: GREEN PLAINS INC;81793']
# row #5413['Velliv;company_name: GOLDCREST CO LTD;81562']
# row #5414['Velliv;company_name: SOURCENEXT CORP;81523']
# row #5415['Velliv;company_name: CEDAR WOODS PROPERTIES LTD;81331']
# row #5416['Velliv;company_name: CINCINNATI BELL INC;79982']
# row #5417['Velliv;company_name: OSAKA SODA CO LTD;79481']
# row #5418['Velliv;company_name: AMALGAMATED FINANCIAL CORP;79289']
# row #5419['Velliv;company_name: KAPPA CREATE CO LTD;79250']
# row #5420['Velliv;company_name: KENEDIX RESIDENTIAL NEXT INV;78557']
# row #5421['Velliv;company_name: WALLBRIDGE MINING CO LTD;78518']
# row #5422['Velliv;company_name: TAIKO PHARMACEUTICAL CO LTD;78249']
# row #5423['Velliv;company_name: CHATWORK CO LTD;77709']
# row #5424['Velliv;company_name: TX GROUP AG;77632']
# row #5425['Velliv;company_name: ZIGEXN CO LTD;77516']
# row #5426['Velliv;company_name: NIPPON PARKING DEVELOPMENT C;77439']
# row #5427['Velliv;company_name: STOLT-NIELSEN LTD;77324']
# row #5428['Velliv;company_name: EVERTZ TECHNOLOGIES LTD;77285']
# row #5429['Velliv;company_name: SHIN NIPPON AIR TECHNOLOGIES;77170']
# row #5430['Velliv;company_name: MATSUYA CO LTD;76553']
# row #5431['Velliv;company_name: TOSEI CORP;76091']
# row #5432['Velliv;company_name: FACC AG;75166']
# row #5433['Velliv;company_name: TAMA HOME CO LTD;75089']
# row #5434['Velliv;company_name: PIOLAX INC;75012']
# row #5435['Velliv;company_name: APOLLO FUTURE MOBILITY GRP L;74627']
# row #5436['Velliv;company_name: MEIRAGTX HOLDINGS PLC;73856']
# row #5437['Velliv;company_name: AI INSIDE INC;73124']
# row #5438['Velliv;company_name: SELVAAG BOLIG ASA;73124']
# row #5439['Velliv;company_name: KEIYO CO LTD;72778']
# row #5440['Velliv;company_name: AOKI HOLDINGS INC;72662']
# row #5441['Velliv;company_name: HOTEL CHOCOLAT GROUP PLC;72546']
# row #5442['Velliv;company_name: VPOWER GROUP INTERNATIONAL H;72315']
# row #5443['Velliv;company_name: PROTO CORP;71660']
# row #5444['Velliv;company_name: MITSUI DM SUGAR HOLDINGS CO;71275']
# row #5445['Velliv;company_name: TOC CO LTD;70659']
# row #5446['Velliv;company_name: KALA PHARMACEUTICALS INC;69310']
# row #5447['Velliv;company_name: RESTAURANT BRANDS NZ LTD;69118']
# row #5448['Velliv;company_name: DAIWA INDUSTRIES LTD;68732']
# row #5449['Velliv;company_name: FUTABA INDUSTRIAL CO LTD;68463']
# row #5450['Velliv;company_name: DAIKEN CORP;68270']
# row #5451['Velliv;company_name: FUJIO FOOD GROUP INC;68000']
# row #5452['Velliv;company_name: SMCP SA;67962']
# row #5453['Velliv;company_name: CENTRAL SECURITY PATROLS CO;67499']
# row #5454['Velliv;company_name: FILA  SPA;67461']
# row #5455['Velliv;company_name: JAPAN INVESTMENT ADVISER CO;65881']
# row #5456['Velliv;company_name: NORWAY ROYAL SALMON ASA;65727']
# row #5457['Velliv;company_name: CANON ELECTRONICS INC;65496']
# row #5458['Velliv;company_name: FORFARMERS NV;65072']
# row #5459['Velliv;company_name: EBASE CO LTD;64957']
# row #5460['Velliv;company_name: TACHI-S CO LTD;64841']
# row #5461['Velliv;company_name: TPR CO LTD;64456']
# row #5462['Velliv;company_name: SPARX GROUP CO LTD;64225']
# row #5463['Velliv;company_name: LIFULL CO LTD;63724']
# row #5464['Velliv;company_name: RUSH ENTERPRISES INC - CL B;63030']
# row #5465['Velliv;company_name: DAINICHISEIKA COLOR & CHEM;62491']
# row #5466['Velliv;company_name: AICHI CORP;62298']
# row #5467['Velliv;company_name: NAPHTHA ISRAEL PETROLEUM CRP;61566']
# row #5468['Velliv;company_name: ADVAN CO LTD;61181']
# row #5469['Velliv;company_name: MOLECULAR TEMPLATES INC;60179']
# row #5470['Velliv;company_name: PREFERRED BANK/LOS ANGELES;60141']
# row #5471['Velliv;company_name: HALOWS CO LTD;59910']
# row #5472['Velliv;company_name: KOSHIDAKA HOLDINGS CO LTD;59409']
# row #5473['Velliv;company_name: OKUWA CO LTD;59293']
# row #5474['Velliv;company_name: MEDARTIS HOLDING AG;59216']
# row #5475['Velliv;company_name: MTI LTD;58985']
# row #5476['Velliv;company_name: SANSHIN ELECTRONICS CO LTD;58946']
# row #5477['Velliv;company_name: AUSTRALIAN AGRICULTURAL CO;58908']
# row #5478['Velliv;company_name: MATSUDA SANGYO CO LTD;58561']
# row #5479['Velliv;company_name: FUJIYA CO LTD;58291']
# row #5480['Velliv;company_name: RIKEN KEIKI CO LTD;57906']
# row #5481['Velliv;company_name: HT&E LTD;57328']
# row #5482['Velliv;company_name: AKOUOS INC;57213']
# row #5483['Velliv;company_name: SOFTWARE SERVICE INC;56712']
# row #5484['Velliv;company_name: GRUPO EMPRESARIAL SAN JOSE;56635']
# row #5485['Velliv;company_name: MARVELOUS INC;56018']
# row #5486['Velliv;company_name: DUSKIN CO LTD;55286']
# row #5487['Velliv;company_name: PROMOTORA DE INFORMACIONES-A;54323']
# row #5488['Velliv;company_name: LIBERTY MEDIA CORP-BRAVES A;53630']
# row #5489['Velliv;company_name: DAIWA HOUSE REIT INVESTMENT;53602']
# row #5490['Velliv;company_name: VT HOLDINGS CO LTD;52782']
# row #5491['Velliv;company_name: ICHIKOH INDUSTRIES LTD;51588']
# row #5492['Velliv;company_name: AGRANA BETEILIGUNGS AG;50817']
# row #5493['Velliv;company_name: TONAMI HOLDINGS CO LTD;50702']
# row #5494['Velliv;company_name: KINTETSU DEPT STORE CO LTD;49970']
# row #5495['Velliv;company_name: WORLD HOLDINGS CO LTD;49661']
# row #5496['Velliv;company_name: HEMISPHERE MEDIA GROUP INC;49623']
# row #5497['Velliv;company_name: CONEXIO CORP;49084']
# row #5498['Velliv;company_name: WDB HOLDINGS CO LTD;47658']
# row #5499['Velliv;company_name: DAIICHI JITSUGYO CO LTD;46733']
# row #5500['Velliv;company_name: ARNOLDO MONDADORI EDITORE;46387']
# row #5501['Velliv;company_name: PRIMARY HEALTH PROPERTIES;46310']
# row #5502['Velliv;company_name: CENTRAL PACIFIC FINANCIAL CO;45886']
# row #5503['Velliv;company_name: STARZEN CO LTD;45886']
# row #5504['Velliv;company_name: TOYO TANSO CO LTD;45886']
# row #5505['Velliv;company_name: TATSUTA ELEC WIRE & CABLE;45077']
# row #5506['Velliv;company_name: SILVERLAKE AXIS LTD;44730']
# row #5507['Velliv;company_name: ABC ARBITRAGE;44345']
# row #5508['Velliv;company_name: BEST WORLD INTERNATIONAL LTD;44113']
# row #5509['Velliv;company_name: CRAWFORD & COMPANY -CL A;43381']
# row #5510['Velliv;company_name: BLACK DIAMOND THERAPEUTICS I;42495']
# row #5511['Velliv;company_name: XEBIO HOLDINGS CO LTD;42187']
# row #5512['Velliv;company_name: COMPAGNIE DES ALPES;41494']
# row #5513['Velliv;company_name: GROUPE GUILLIN;41224']
# row #5514['Velliv;company_name: SINFONIA TECHNOLOGY CO LTD;40877']
# row #5515['Velliv;company_name: GUERBET;40723']
# row #5516['Velliv;company_name: CORBY SPIRIT AND WINE LTD;40338']
# row #5517['Velliv;company_name: ROCK FIELD CO LTD;40261']
# row #5518['Velliv;company_name: SMARTONE TELECOMMUNICATIONS;39452']
# row #5519['Velliv;company_name: COSCO SHIPPING INTERNATIONAL;38527']
# row #5520['Velliv;company_name: ST CORP;37757']
# row #5521['Velliv;company_name: SHINNIHON CORP;36639']
# row #5522['Velliv;company_name: NAGATANIEN HOLDINGS CO LTD;34944']
# row #5523['Velliv;company_name: INDUSTRIAL & INFRASTRUCTURE;34674']
# row #5524['Velliv;company_name: NIHON CHOUZAI CO LTD;34096']
# row #5525['Velliv;company_name: DAIKYONISHIKAWA CORP;33865']
# row #5526['Velliv;company_name: MIE KOTSU GROUP HOLDINGS INC;33095']
# row #5527['Velliv;company_name: DANIELI & CO;33056']
# row #5528['Velliv;company_name: HOMESTREET INC;31053']
# row #5529['Velliv;company_name: LUTHER BURBANK CORP;30860']
# row #5530['Velliv;company_name: KAMEI CORP;30629']
# row #5531['Velliv;company_name: VAN DE VELDE NV;30513']
# row #5532['Velliv;company_name: SUNCITY GROUP HOLDINGS LTD;30398']
# row #5533['Velliv;company_name: TAKASAGO INTERNATIONAL CORP;29435']
# row #5534['Velliv;company_name: ELEMATEC CORP;28549']
# row #5535['Velliv;company_name: ALLEGIANCE BANCSHARES INC;26776']
# row #5536['Velliv;company_name: NS UNITED KAIUN KAISHA LTD;26430']
# row #5537['Velliv;company_name: OSAKA STEEL CO LTD;24311']
# row #5538['Velliv;company_name: SG FLEET GROUP LTD;23964']
# row #5539['Velliv;company_name: LAR ESPANA REAL ESTATE SOCIM;22307']
# row #5540['Velliv;company_name: LA DORIA SPA;21729']
# row #5541['Velliv;company_name: TRUSTCO BANK CORP NY;20805']
# row #5542['Velliv;company_name: OXLEY HOLDINGS LTD;20728']
# row #5543['Velliv;company_name: NITTO KOHKI CO LTD;19649']
# row #5544['Velliv;company_name: EAGLE INDUSTRY CO LTD;18377']
# row #5545['Velliv;company_name: JSP CORP;17414']
# row #5546['Velliv;company_name: NIHON NOHYAKU CO LTD;16490']
# row #5547['Velliv;company_name: COMPAGNIE DES ALPES-RTS;15180']
# row #5548['Velliv;company_name: CLAS OHLSON AB-B SHS;13446']
# row #5549['Velliv;company_name: WOWOW INC;13138']
# row #5550['Velliv;company_name: MEDIPAL HOLDINGS CORP;11688']
# row #5551['Velliv;company_name: SACYR SA-RTS;11365']
# row #5552['Velliv;company_name: EAGLE HOSPITALITY TRUST;10633']
# row #5553['Velliv;company_name: UUUM CO LTD;8399']
# row #5554['Velliv;company_name: MAPLETREE INDUSTRIA-RIGHTS;5355']
# row #5555['Velliv;company_name: AMC ENTERTAINMENT HOLDINGS LOCK UP Prvt;4422']
# row #5556['Velliv;company_name: JAPAN HOTEL REIT INVESTMENT;3622']
# row #5557['Velliv;company_name: GENTING SINGAPORE LTD;403']
# row #5558['Velliv;company_name: PFA Holding;268']
# row #5559['Velliv;company_name: AUTOGRILL SPA - RTS;39']

# %%
import csv

filename = "/Users/halla/Documents/Redi school/ReDi_DataAnalytics_Repo/Homework/Halla/Pension fund excercise/pension_fund_data.csv"

with open(filename) as file:
    reader = csv.reader(file)
    line = list(reader)
    print(line[0])
    print (len(line[0]))
# Out:
# ['pension_fund;company ;invested_amount']
# 1

# %%
import csv

filename = "/Users/halla/Documents/Redi school/ReDi_DataAnalytics_Repo/Homework/Halla/Pension fund excercise/pension_fund_data.csv"

with open(filename) as file:
    reader = csv.reader(file)
    
    for row in reader:
        if row != 3
        print (3)
# Out:
#   File "/var/folders/t4/q9ls5g392w555s2fpfxt52nr0000gn/T/ipykernel_69481/2809393088.py", line 9
#     if row != 3
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Hi! Today you will play with NaN values and another Data Manipulation methods. Let us know if you need help and also if you need more challenges on that :)

# %% [markdown]
# #### The dataset that you will use is again recipes.csv. You can either use your own or the one in the subfolder "data". Do not forget to import the necessary libraries!

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data/recipes.csv", index_col=0)
df
# Out:
#      vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0          True        True       True        False          1.0
# 1          True        True      False        False          0.0
# 2         False       False      False        False          3.0
# 3          True       False       True        False          2.0
# 4         False        True      False        False         31.0
# ..          ...         ...        ...          ...          ...
# 145       False        True       True        False         18.0
# 146        True       False      False        False          1.0
# 147        True        True       True         True         93.0
# 148        True        True      False        False          5.0
# 149        True        True       True         True        100.0
#
#      aggregateLikes      id  \
# 0                 3  633998
# 1                 1  634426
# 2                 1  635085
# 3                 1  663229
# 4                 3  651437
# ...

# %%
# Function to describe data frame
def describe_data(df):
    print("Data Types:")
    print(df.dtypes)
    print("Rows and Columns:")
    print(df.shape)
    print("Column Names:")
    print(df.columns)

describe_data(df)
# Out:
# Data Types:
# vegetarian                       bool
# glutenFree                       bool
# dairyFree                        bool
# veryHealthy                      bool
# healthScore                   float64
#                                ...
# CalciumpercentOfDailyNeed     float64
# AlcoholAmount                 float64
# AlcoholpercentOfDailyNeed     float64
# CaffeineAmount                float64
# CaffeinepercentOfDailyNeed    float64
# Length: 78, dtype: object
# Rows and Columns:
# (150, 78)
# Column Names:
# Index(['vegetarian', 'glutenFree', 'dairyFree', 'veryHealthy', 'healthScore',
#        'aggregateLikes', 'id', 'title', 'pricePerServing', 'readyInMinutes',
#        'servings', 'sourceUrl', 'CaloriesAmount', 'CaloriespercentOfDailyNeed',
#        'FatAmount', 'FatpercentOfDailyNeed', 'SaturatedFatAmount',
#        'SaturatedFatpercentOfDailyNeed', 'CarbohydratesAmount',
#        'CarbohydratespercentOfDailyNeed', 'NetCarbohydratesAmount',
# ...

# %% [markdown]
# #### Print the names of Columns that have null values

# %%
df.isnull().sum()
# Out:
# vegetarian                      0
# glutenFree                      0
# dairyFree                       0
# veryHealthy                     0
# healthScore                     0
#                              ...
# CalciumpercentOfDailyNeed       8
# AlcoholAmount                 129
# AlcoholpercentOfDailyNeed     129
# CaffeineAmount                141
# CaffeinepercentOfDailyNeed    141
# Length: 78, dtype: int64

# %%
# df.isnull().any() generates a boolean array.Can use it as a condition to df.columns
df.columns[df.isnull().any()]
# Out:
# Index(['FiberAmount', 'FiberpercentOfDailyNeed', 'VitaminB6Amount',
#        'VitaminB6percentOfDailyNeed', 'ManganeseAmount',
#        'ManganesepercentOfDailyNeed', 'SeleniumAmount',
#        'SeleniumpercentOfDailyNeed', 'PotassiumAmount',
#        'PotassiumpercentOfDailyNeed', 'VitaminB2Amount',
#        'VitaminB2percentOfDailyNeed', 'VitaminCAmount',
#        'VitaminCpercentOfDailyNeed', 'PhosphorusAmount',
#        'PhosphoruspercentOfDailyNeed', 'FolateAmount',
#        'FolatepercentOfDailyNeed', 'VitaminB5Amount',
#        'VitaminB5percentOfDailyNeed', 'MagnesiumAmount',
#        'MagnesiumpercentOfDailyNeed', 'IronAmount', 'IronpercentOfDailyNeed',
#        'VitaminKAmount', 'VitaminKpercentOfDailyNeed', 'CopperAmount',
#        'CopperpercentOfDailyNeed', 'VitaminAAmount',
#        'VitaminApercentOfDailyNeed', 'VitaminB12Amount',
#        'VitaminB12percentOfDailyNeed', 'VitaminDAmount',
#        'VitaminDpercentOfDailyNeed', 'ZincAmount', 'ZincpercentOfDailyNeed',
# ...

# %%
[col for col in df.columns if df[col].isnull().any()]
# Out:
# ['FiberAmount',
#  'FiberpercentOfDailyNeed',
#  'VitaminB6Amount',
#  'VitaminB6percentOfDailyNeed',
#  'ManganeseAmount',
#  'ManganesepercentOfDailyNeed',
#  'SeleniumAmount',
#  'SeleniumpercentOfDailyNeed',
#  'PotassiumAmount',
#  'PotassiumpercentOfDailyNeed',
#  'VitaminB2Amount',
#  'VitaminB2percentOfDailyNeed',
#  'VitaminCAmount',
#  'VitaminCpercentOfDailyNeed',
#  'PhosphorusAmount',
#  'PhosphoruspercentOfDailyNeed',
#  'FolateAmount',
#  'FolatepercentOfDailyNeed',
#  'VitaminB5Amount',
#  'VitaminB5percentOfDailyNeed',
#  'MagnesiumAmount',
#  'MagnesiumpercentOfDailyNeed',
#  'IronAmount',
#  'IronpercentOfDailyNeed',
#  'VitaminKAmount',
#  'VitaminKpercentOfDailyNeed',
#  'CopperAmount',
#  'CopperpercentOfDailyNeed',
#  'VitaminAAmount',
#  'VitaminApercentOfDailyNeed',
#  'VitaminB12Amount',
#  'VitaminB12percentOfDailyNeed',
#  'VitaminDAmount',
#  'VitaminDpercentOfDailyNeed',
#  'ZincAmount',
#  'ZincpercentOfDailyNeed',
#  'VitaminEAmount',
# ...

# %% [markdown]
# #### Print the recipes with the highest number of aggregateLikes

# %%
df.aggregateLikes.sort_values()
df.loc[50,'title']
# Out:
# 'Slow Cooker Spicy Hot Wings'

# %% [markdown]
# #### Handle the missing values of “calcium percent of Daily need”. Sort the resulting DataFrame by id column.

# %%
value_to_fill = df.CalciumpercentOfDailyNeed.median()
new_df = df.copy()
new_df.CalciumpercentOfDailyNeed.fillna(value_to_fill, inplace=True)
new_df.sort_values(by=['id'], inplace=True)
new_df
# Out:
#      vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 83        False       False      False        False          5.0
# 43        False       False      False        False         44.0
# 104       False       False      False        False          4.0
# 95        False        True       True        False          9.0
# 52        False       False      False        False          2.0
# ..          ...         ...        ...          ...          ...
# 134        True        True       True         True         77.0
# 30         True        True       True        False         17.0
# 118       False        True       True        False         38.0
# 39         True        True       True        False          7.0
# 67        False        True      False        False         15.0
#
#      aggregateLikes       id                                      title  \
# 83                0    45945                          Oeufs En Meurette
# ...

# %% [markdown]
# #### Delete the columns that have null values == 141

# %%
col_to_drop = [col for col in df.columns if df[col].isnull().sum() == 141]
df.drop(col_to_drop, axis=1)
# Out:
#      vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0          True        True       True        False          1.0
# 1          True        True      False        False          0.0
# 2         False       False      False        False          3.0
# 3          True       False       True        False          2.0
# 4         False        True      False        False         31.0
# ..          ...         ...        ...          ...          ...
# 145       False        True       True        False         18.0
# 146        True       False      False        False          1.0
# 147        True        True       True         True         93.0
# 148        True        True      False        False          5.0
# 149        True        True       True         True        100.0
#
#      aggregateLikes      id  \
# 0                 3  633998
# 1                 1  634426
# 2                 1  635085
# 3                 1  663229
# 4                 3  651437
# ...

# %% [markdown]
# #### Print the title of the recipes that are vegetarian == TRUE and glutenFree == True

# %%
vegetarian_glutenFree = df[(df.vegetarian == True) & (df.glutenFree == True)]
vegetarian_glutenFree.title
# Out:
# 0                              Banana Blueberry Pancakes
# 1                Basil and Orange Confit Compound Butter
# 14                            Spicy Carrot Amaranth Soup
# 15                                            Nutty Rice
# 20                           Fire Roasted Tomato Chutney
# 22                                 Butternut Squash Soup
# 24                         Green Beans with Garlic Chips
# 27                                Easy Eggplant Parmesan
# 29                                            Kappa Maki
# 30                              Vegan Chana Masala Curry
# 31     Grilled Peach Melba with Vanilla Bean Frozen Y...
# 33                             Detox Orange Carrot Juice
# 37                      Roasted Asparagus with Egg Salad
# 39                   Three Ingredient Frozen Pina Colada
# 42                               Peach Coconut Ice Cream
# 57     Sautéed Balsamic Green Beans With Cherry Tomatoes
# ...

# %% [markdown]
# #### How many vegan recipes are there (Vegan = Vegetarian and dairy free)?

# %%
vegan = df[(df.vegetarian == True) & (df.dairyFree == True)]
vegan.title.count()
# Out:
# 29

# %% [markdown]
# #### Compare the average amount of Vitamin B12 for the vegan and non-vegan recipes. How reliable are the results?

# %%
non_vegan = df[(df.vegetarian == False) | (df.dairyFree == False)]
non_vegan.VitaminB12Amount.isnull().sum()
vegan.VitaminB12Amount.isnull().sum()
print(f"Average amount of Vitamin B12 for the vegan recipes: {vegan.VitaminB12Amount.mean()}")
print(f"Average amount of Vitamin B12 for the non-vegan recipes: {non_vegan.VitaminB12Amount.mean()}")
print(f"The result is not reliable because {vegan.VitaminB12Amount.isnull().sum()} vegan recipes are null values, in the total of {vegan.title.count()} vegan recipes")
# Out:
# Average amount of Vitamin B12 for the vegan recipes: 0.24333333333333332
# Average amount of Vitamin B12 for the non-vegan recipes: 1.0345555555555552
# The result is not reliable because 26 vegan recipes are null values, in the total of 29 vegan recipes

# %% [markdown]
# #### Compare the average health Score for both types of recipes (vegan vs non-vegan).

# %%
print(f"Average health score for the vegan recipes: {vegan.healthScore.mean()}")
print(f"Average health score for the non-vegan recipes: {non_vegan.healthScore.mean()}")
# Out:
# Average health score for the vegan recipes: 27.724137931034484
# Average health score for the non-vegan recipes: 18.785123966942148

# %% [markdown]
# #### Create a new column: "VeganWeek" where you decrease the price of vegan products by 10%, but only if they already cost more than 100.

# %%
df['VeganWeek'] = np.where((df.vegetarian == True) & (df.dairyFree == True) & (df.pricePerServing > 100), df.pricePerServing*0.9, df.pricePerServing)
df
# Out:
#      vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0          True        True       True        False          1.0
# 1          True        True      False        False          0.0
# 2         False       False      False        False          3.0
# 3          True       False       True        False          2.0
# 4         False        True      False        False         31.0
# ..          ...         ...        ...          ...          ...
# 145       False        True       True        False         18.0
# 146        True       False      False        False          1.0
# 147        True        True       True         True         93.0
# 148        True        True      False        False          5.0
# 149        True        True       True         True        100.0
#
#      aggregateLikes      id  \
# 0                 3  633998
# 1                 1  634426
# 2                 1  635085
# 3                 1  663229
# 4                 3  651437
# ...

# %% [markdown]
# #### Among the non-vegan recipes, find the one requiring most time to prepare. How is it called?

# %%
non_vegan.title[non_vegan.readyInMinutes.idxmax()]
# Out:
# 'Oeufs En Meurette'

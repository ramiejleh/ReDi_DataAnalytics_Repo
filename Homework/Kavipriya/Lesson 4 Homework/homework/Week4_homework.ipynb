# %% [markdown]
# #### Hi! Today you will play with NaN values and another Data Manipulation methods. Let us know if you need help and also if you need more challenges on that :)

# %% [markdown]
# #### The dataset that you will use is again recipes.csv. You can either use your own or the one in the subfolder "data". Do not forget to import the necessary libraries!

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("data/recipes.csv", index_col=0)
df.head()
# Out:
#    vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0        True        True       True        False          1.0
# 1        True        True      False        False          0.0
# 2       False       False      False        False          3.0
# 3        True       False       True        False          2.0
# 4       False        True      False        False         31.0
#
#    aggregateLikes      id                                    title  \
# 0               3  633998                Banana Blueberry Pancakes
# 1               1  634426  Basil and Orange Confit Compound Butter
# 2               1  635085                 Black Bottom Banana Bars
# 3               1  663229      The Best Raw Chocolate Chip Cookies
# 4               3  651437      Mediterranean Spinach Artichoke Dip
#
#    pricePerServing  readyInMinutes  ...  VitaminB3Amount  \
# 0            55.79              45  ...             0.49
# 1            15.07              45  ...              NaN
# 2            78.85              45  ...             2.63
# 3            54.64              45  ...             0.65
# 4           115.26              45  ...             0.66
#
#   VitaminB3percentOfDailyNeed  VitaminB1Amount  VitaminB1percentOfDailyNeed  \
# 0                        2.44             0.03                         2.26
# 1                         NaN              NaN                          NaN
# 2                       13.13             0.32                        21.09
# 3                        3.26             0.10                         6.47
# 4                        3.29             0.07                         4.64
#
#    CalciumAmount  CalciumpercentOfDailyNeed  AlcoholAmount  \
# 0          18.11                       1.81            NaN
# 1            NaN                        NaN            NaN
# 2         100.80                      10.08           0.28
# 3          26.79                       2.68            NaN
# 4         162.84                      16.28            NaN
#
#    AlcoholpercentOfDailyNeed  CaffeineAmount  CaffeinepercentOfDailyNeed
# 0                        NaN             NaN                         NaN
# 1                        NaN             NaN                         NaN
# 2                       1.53            9.89                         3.3
# 3                        NaN             NaN                         NaN
# 4                        NaN             NaN                         NaN
#
# [5 rows x 78 columns]

# %% [markdown]
# #### Print the names of Columns that have null values

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['FiberAmount',
#  'FiberpercentOfDailyNeed',
#  'VitaminB6Amount',
#  'VitaminB6percentOfDailyNeed',
#  'ManganeseAmount',
#  'ManganesepercentOfDailyNeed',
#  'SeleniumAmount',
#  'SeleniumpercentOfDailyNeed',
#  'PotassiumAmount',
#  'PotassiumpercentOfDailyNeed',
#  'VitaminB2Amount',
#  'VitaminB2percentOfDailyNeed',
#  'VitaminCAmount',
#  'VitaminCpercentOfDailyNeed',
#  'PhosphorusAmount',
#  'PhosphoruspercentOfDailyNeed',
#  'FolateAmount',
#  'FolatepercentOfDailyNeed',
#  'VitaminB5Amount',
#  'VitaminB5percentOfDailyNeed',
#  'MagnesiumAmount',
#  'MagnesiumpercentOfDailyNeed',
#  'IronAmount',
#  'IronpercentOfDailyNeed',
#  'VitaminKAmount',
#  'VitaminKpercentOfDailyNeed',
#  'CopperAmount',
#  'CopperpercentOfDailyNeed',
#  'VitaminAAmount',
#  'VitaminApercentOfDailyNeed',
#  'VitaminB12Amount',
#  'VitaminB12percentOfDailyNeed',
#  'VitaminDAmount',
#  'VitaminDpercentOfDailyNeed',
#  'ZincAmount',
#  'ZincpercentOfDailyNeed',
#  'VitaminEAmount',
#  'VitaminEpercentOfDailyNeed',
#  'VitaminB3Amount',
#  'VitaminB3percentOfDailyNeed',
#  'VitaminB1Amount',
#  'VitaminB1percentOfDailyNeed',
#  'CalciumAmount',
#  'CalciumpercentOfDailyNeed',
#  'AlcoholAmount',
#  'AlcoholpercentOfDailyNeed',
#  'CaffeineAmount',
#  'CaffeinepercentOfDailyNeed']

# %% [markdown]
# #### Print the recipes with the highest number of aggregateLikes

# %%
column = df["aggregateLikes"]
max_value = column.max()
print(max_value)

i = df['aggregateLikes'].idxmax()
print(i)
# display the name corresponding this index
print(df['title'][i])
# Out:
# 16911
# 50
# Slow Cooker Spicy Hot Wings

# %% [markdown]
# #### Handle the missing values of “calcium percent of Daily need”. Sort the resulting DataFrame by id column.

# %%
#Can you please give me some hint. how to handle the missing values
# Out:
# 83       45945
# 43      622825
# 104     631769
# 95      632084
# 52      632101
#         ...
# 134    1096268
# 30     1096306
# 118    1096323
# 39     1098357
# 67     1416203
# Name: id, Length: 150, dtype: int64

# %% [markdown]
# #### Delete the columns that have null values == 141

# %%
# I didnt understand the question delete the columns ? or rows?  why it is mentioned 141

# %% [markdown]
# #### Print the title of the recipes that are vegetarian == TRUE and glutenFree == True

# %%
new_df = df.loc[(df.vegetarian == True ) & (df.glutenFree == True )]
new_df['title']
# Out:
# 0                              Banana Blueberry Pancakes
# 1                Basil and Orange Confit Compound Butter
# 14                            Spicy Carrot Amaranth Soup
# 15                                            Nutty Rice
# 20                           Fire Roasted Tomato Chutney
# 22                                 Butternut Squash Soup
# 24                         Green Beans with Garlic Chips
# 27                                Easy Eggplant Parmesan
# 29                                            Kappa Maki
# 30                              Vegan Chana Masala Curry
# 31     Grilled Peach Melba with Vanilla Bean Frozen Y...
# 33                             Detox Orange Carrot Juice
# 37                      Roasted Asparagus with Egg Salad
# 39                   Three Ingredient Frozen Pina Colada
# 42                               Peach Coconut Ice Cream
# 57     Sautéed Balsamic Green Beans With Cherry Tomatoes
# 61                              Ginger Melon Side Salad
# 69                      Chicken with Avocado Peach Salsa
# 72                             EASY, CUMIN-LENTIL SPREAD
# 80                                 Luscious Palak Paneer
# 85                                             Beet Slaw
# 93             Roasted Strawberry Coconut Milk Ice Cream
# 96                                    Breakfast Porridge
# 97     Peanut Butter Cookies with Flax Seeds and Choc...
# 100                                  Blender Carrot Soup
# 101                                      Dandelion pesto
# 102                                Coconut Flour Muffins
# 106                              Japanese Cucumber Salad
# 107                           Blueberry Mojito Popsicles
# 119                                     Fried Brown Rice
# 123                                 Seasonal Autumn Stew
# 126    Slow Cooker Healthy Sweet Potato Soup with Coc...
# 129    Blueberry, Persimmon Smoothie with Banana and ...
# 131                              Mango Cranberry Sherbet
# 132                          Cherries and Yogurt Parfait
# 133                              The Pearhattan Cocktail
# 134            Garlic-Roasted Brussels Sprouts Side Dish
# 139                                  Layered Greek Salad
# 143                      Stir Fried Cabbage and Tomatoes
# 147                            Cauliflower Chickpea Stew
# 148    Sautéed Balsamic Green Beans With Cherry Tomatoes
# 149          Indian-Style Dill and Turmeric Potato Salad
# Name: title, dtype: object

# %% [markdown]
# #### How many vegan recipes are there (Vegan = Vegetarian and dairy free)?

# %%
vegandf = df.loc[(df.vegetarian == True ) & (df.dairyFree == True )]
#vegandf
len(vegandf.index)
# Out:
# 29

# %% [markdown]
# #### Compare the average amount of Vitamin B12 for the vegan and non-vegan recipes. How reliable are the results?

# %%
nonvegandf = df.loc[(df.vegetarian == False )]
nonvegandf
averagevegan = vegandf["VitaminB12Amount"].mean()
averagenonvegan = nonvegandf["VitaminB12Amount"].mean()
averagevegan,averagenonvegan
# Out:
# (0.24333333333333332, 1.235384615384615)

# %% [markdown]
# #### Compare the average health Score for both types of recipes (vegan vs non-vegan).

# %%
avgHSNV = nonvegandf["healthScore"].mean()
avgHSVEG = vegandf["healthScore"].mean()
avgHSNV,avgHSVEG
# Out:
# (22.107142857142858, 27.724137931034484)

# %% [markdown]
# #### Create a new column: "VeganWeek" where you decrease the price of vegan products by 10%, but only if they already cost more than 100.

# %%
#df.loc[(df.vegetarian == True ) & (df.dairyFree == True) & ( df.pricePerServing > 100 )]
df.loc[(df.vegetarian == True ) & (df.dairyFree == True) & ( df.pricePerServing > 100 ),"pricePerServing"]= df.pricePerServing * .9
#df
df["VeganWeek"] = np.where((df.vegetarian == True ) & (df.dairyFree == True ),  "VeganWeek " + df.title, "NOT Vegan " + df.title)
#df.loc[(df.vegetarian == True ) & (df.dairyFree == True) & ( df.pricePerServing > 100 )]
df
# Out:
#      vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 9          True       False       True         True         62.0
# 14         True        True       True        False         16.0
# 30         True        True       True        False         17.0
# 39         True        True       True        False          7.0
# 61         True        True       True        False         13.0
# 93         True        True       True        False          4.0
# 101        True        True       True        False         10.0
# 107        True        True       True        False          3.0
# 119        True        True       True        False         30.0
# 123        True        True       True         True        100.0
# 126        True        True       True        False         21.0
# 133        True        True       True        False          7.0
# 134        True        True       True         True         77.0
# 147        True        True       True         True         93.0
# 149        True        True       True         True        100.0
#
#      aggregateLikes       id  \
# 9                 1  1095768
# 14                2   661036
# 30                1  1096306
# 39                6  1098357
# 61                1  1095692
# 93                2   658665
# 101             103   641227
# 107               1   635495
# 119               1   643674
# 123               1   659689
# 126               1  1096231
# 133               6   663313
# 134               1  1096268
# 147               2   637297
# 149               4   647875
#
#                                                  title  pricePerServing  \
# 9    Bulgur Wheat Salad with Chickpeas, Bell Pepper...          206.352
# 14                          Spicy Carrot Amaranth Soup          198.477
# 30                            Vegan Chana Masala Curry          149.301
# 39                 Three Ingredient Frozen Pina Colada          193.140
# 61                            Ginger Melon Side Salad           197.730
# 93           Roasted Strawberry Coconut Milk Ice Cream          129.339
# 101                                    Dandelion pesto          119.259
# 107                         Blueberry Mojito Popsicles          103.374
# 119                                   Fried Brown Rice          170.028
# 123                               Seasonal Autumn Stew          155.484
# 126  Slow Cooker Healthy Sweet Potato Soup with Coc...          376.272
# 133                            The Pearhattan Cocktail          458.901
# 134          Garlic-Roasted Brussels Sprouts Side Dish          153.306
# 147                          Cauliflower Chickpea Stew          125.352
# 149        Indian-Style Dill and Turmeric Potato Salad          105.516
#
#      readyInMinutes  ...  VitaminB3percentOfDailyNeed VitaminB1Amount  \
# 9                30  ...                        27.55            0.37
# 14               45  ...                         5.94            0.09
# 30               30  ...                        10.71            0.20
# 39                5  ...                         5.25            0.19
# 61               10  ...                         8.02            0.15
# 93               45  ...                         4.14            0.03
# 101              45  ...                         1.47            0.10
# 107              45  ...                         1.35            0.02
# 119              25  ...                        35.32            0.42
# 123              45  ...                        30.77            0.38
# 126             275  ...                         9.99            0.26
# 133              45  ...                         5.44            0.10
# 134              35  ...                         6.13            0.23
# 147              45  ...                        23.83            0.45
# 149              30  ...                         1.05             NaN
#
#      VitaminB1percentOfDailyNeed  CalciumAmount  CalciumpercentOfDailyNeed  \
# 9                          24.71         151.83                      15.18
# 14                          5.91         103.27                      10.33
# 30                         13.09         154.27                      15.43
# 39                         12.66          52.87                       5.29
# 61                          9.86          31.29                       3.13
# 93                          2.32          26.76                       2.68
# 101                         6.80          19.65                       1.96
# 107                         1.56          16.49                       1.65
# 119                        27.99         140.79                      14.08
# 123                        25.44         213.53                      21.35
# 126                        17.24         104.01                      10.40
# 133                         6.92          63.01                       6.30
# 134                        15.57          83.41                       8.34
# 147                        29.70         141.16                      14.12
# 149                          NaN          27.96                       2.80
#
#      AlcoholAmount  AlcoholpercentOfDailyNeed  CaffeineAmount  \
# 9              NaN                        NaN             NaN
# 14             NaN                        NaN             NaN
# 30             NaN                        NaN             NaN
# 39           13.36                      74.22             NaN
# 61             NaN                        NaN             NaN
# 93             NaN                        NaN             NaN
# 101            NaN                        NaN             NaN
# 107           1.25                       6.96             NaN
# 119            NaN                        NaN             NaN
# 123            NaN                        NaN             NaN
# 126            NaN                        NaN             NaN
# 133          21.31                     118.40             NaN
# 134            NaN                        NaN             NaN
# 147            NaN                        NaN             NaN
# 149            NaN                        NaN             NaN
#
#      CaffeinepercentOfDailyNeed  \
# 9                           NaN
# 14                          NaN
# 30                          NaN
# 39                          NaN
# 61                          NaN
# 93                          NaN
# 101                         NaN
# 107                         NaN
# 119                         NaN
# 123                         NaN
# 126                         NaN
# 133                         NaN
# 134                         NaN
# 147                         NaN
# 149                         NaN
#
#                                              VeganWeek
# 9    VeganWeek Bulgur Wheat Salad with Chickpeas, B...
# 14                VeganWeek Spicy Carrot Amaranth Soup
# 30                  VeganWeek Vegan Chana Masala Curry
# 39       VeganWeek Three Ingredient Frozen Pina Colada
# 61                  VeganWeek Ginger Melon Side Salad
# 93   VeganWeek Roasted Strawberry Coconut Milk Ice ...
# 101                          VeganWeek Dandelion pesto
# 107               VeganWeek Blueberry Mojito Popsicles
# 119                         VeganWeek Fried Brown Rice
# 123                     VeganWeek Seasonal Autumn Stew
# 126  VeganWeek Slow Cooker Healthy Sweet Potato Sou...
# 133                  VeganWeek The Pearhattan Cocktail
# 134  VeganWeek Garlic-Roasted Brussels Sprouts Side...
# 147                VeganWeek Cauliflower Chickpea Stew
# 149  VeganWeek Indian-Style Dill and Turmeric Potat...
#
# [15 rows x 79 columns]

# %% [markdown]
# #### Among the non-vegan recipes, find the one requiring most time to prepare. How is it called?

# %%
Msttimeprepare = nonvegandf['readyInMinutes'].idxmax()
print(Msttimeprepare)
# display the name corresponding this index
print(df['title'][Msttimeprepare])
# Out:
# 83
# Oeufs En Meurette

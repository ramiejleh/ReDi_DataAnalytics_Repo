# %%
import pandas

# %%
df= pandas.read_csv("data/output.csv")

# %%
df
# Out:
#            pension_fund                                 company   \
# 0     AkademikerPension                               ANDRITZ AG
# 1     AkademikerPension                               Verbund AG
# 2     AkademikerPension                          Wienerberger AG
# 3     AkademikerPension                                   ams AG
# 4     AkademikerPension                 Oesterreichische Post AG
# ...                 ...                                      ...
# 5552             Velliv  AMC ENTERTAINMENT HOLDINGS LOCK UP Prvt
# 5553             Velliv              JAPAN HOTEL REIT INVESTMENT
# 5554             Velliv                    GENTING SINGAPORE LTD
# 5555             Velliv                              PFA Holding
# 5556             Velliv                      AUTOGRILL SPA - RTS
#
#       invested_amount
# 0             9035890
# 1              535485
# 2              489279
# 3             9582836
# 4              283769
# ...               ...
# ...

# %% [markdown]
# #### Import pandas library using alias pd.

# %%
import pandas as pd

# %% [markdown]
# #### Load file recipes.csv from the data subfolder and store it in a variable df. Use the first column as index.

# %%
df = pd.read_csv("data/Recipes.csv")
df
new_df = pd.read_csv("data/Recipes.csv", index_col=1) ### first column is index 0 :) Remember that indexing starts at 0
new_df
# Out:
#             Unnamed: 0  glutenFree  dairyFree  veryHealthy  healthScore  \
# vegetarian
# True                 0        True       True        False          1.0
# True                 1        True      False        False          0.0
# False                2       False      False        False          3.0
# True                 3       False       True        False          2.0
# False                4        True      False        False         31.0
# ...                ...         ...        ...          ...          ...
# False              145        True       True        False         18.0
# True               146       False      False        False          1.0
# True               147        True       True         True         93.0
# True               148        True      False        False          5.0
# True               149        True       True         True        100.0
#
#             aggregateLikes      id  \
# vegetarian
# True                     3  633998
# True                     1  634426
# False                    1  635085
# True                     1  663229
# False                    3  651437
# ...                    ...     ...
# False                   13  638315
# True                     2  656248
# True                     2  637297
# True                     1  659412
# True                     4  647875
#
#                                                         title  \
# vegetarian
# True                                Banana Blueberry Pancakes
# True                  Basil and Orange Confit Compound Butter
# False                                Black Bottom Banana Bars
# True                      The Best Raw Chocolate Chip Cookies
# False                     Mediterranean Spinach Artichoke Dip
# ...                                                       ...
# False            Chicken Sausage, White Bean and Cabbage Soup
# True                                      Pinot Noir Brownies
# True                                Cauliflower Chickpea Stew
# True        Sautéed Balsamic Green Beans With Cherry Tomatoes
# True              Indian-Style Dill and Turmeric Potato Salad
#
#             pricePerServing  readyInMinutes  ...  VitaminB3Amount  \
# vegetarian                                   ...
# True                  55.79              45  ...             0.49
# True                  15.07              45  ...              NaN
# False                 78.85              45  ...             2.63
# True                  54.64              45  ...             0.65
# False                115.26              45  ...             0.66
# ...                     ...             ...  ...              ...
# False                196.23              45  ...             0.53
# True                  65.76              45  ...             0.21
# True                 139.28              45  ...             4.77
# True                 101.81              45  ...             1.15
# True                 117.24              30  ...             0.21
#
#            VitaminB3percentOfDailyNeed  VitaminB1Amount  \
# vegetarian
# True                              2.44             0.03
# True                               NaN              NaN
# False                            13.13             0.32
# True                              3.26             0.10
# False                             3.29             0.07
# ...                                ...              ...
# False                             2.67             0.15
# True                              1.07             0.03
# True                             23.83             0.45
# True                              5.73             0.12
# True                              1.05              NaN
#
#             VitaminB1percentOfDailyNeed  CalciumAmount  \
# vegetarian
# True                               2.26          18.11
# True                                NaN            NaN
# False                             21.09         100.80
# True                               6.47          26.79
# False                              4.64         162.84
# ...                                 ...            ...
# False                             10.23         102.67
# True                               1.68          19.82
# True                              29.70         141.16
# True                               7.85          55.64
# True                                NaN          27.96
#
#             CalciumpercentOfDailyNeed  AlcoholAmount  \
# vegetarian
# True                             1.81            NaN
# True                              NaN            NaN
# False                           10.08           0.28
# True                             2.68            NaN
# False                           16.28            NaN
# ...                               ...            ...
# False                           10.27            NaN
# True                             1.98           2.48
# True                            14.12            NaN
# True                             5.56            NaN
# True                             2.80            NaN
#
#             AlcoholpercentOfDailyNeed  CaffeineAmount  \
# vegetarian
# True                              NaN             NaN
# True                              NaN             NaN
# False                            1.53            9.89
# True                              NaN             NaN
# False                             NaN             NaN
# ...                               ...             ...
# False                             NaN             NaN
# True                            13.76           10.69
# True                              NaN             NaN
# True                              NaN             NaN
# True                              NaN             NaN
#
#             CaffeinepercentOfDailyNeed
# vegetarian
# True                               NaN
# True                               NaN
# False                             3.30
# True                               NaN
# False                              NaN
# ...                                ...
# False                              NaN
# True                              3.56
# True                               NaN
# True                               NaN
# True                               NaN
#
# [150 rows x 78 columns]

# %% [markdown]
# #### Print the type of variable df.

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Print the number of columns and number of rows of the df DataFrame.

# %%
new_df.shape
# Out:
# (150, 78)

# %% [markdown]
# #### What are the names of the columns in df?

# %%
new_df.columns
# Out:
# Index(['Unnamed: 0', 'glutenFree', 'dairyFree', 'veryHealthy', 'healthScore',
#        'aggregateLikes', 'id', 'title', 'pricePerServing', 'readyInMinutes',
#        'servings', 'sourceUrl', 'CaloriesAmount', 'CaloriespercentOfDailyNeed',
#        'FatAmount', 'FatpercentOfDailyNeed', 'SaturatedFatAmount',
#        'SaturatedFatpercentOfDailyNeed', 'CarbohydratesAmount',
#        'CarbohydratespercentOfDailyNeed', 'NetCarbohydratesAmount',
#        'NetCarbohydratespercentOfDailyNeed', 'SugarAmount',
#        'SugarpercentOfDailyNeed', 'CholesterolAmount',
#        'CholesterolpercentOfDailyNeed', 'SodiumAmount',
#        'SodiumpercentOfDailyNeed', 'ProteinAmount',
#        'ProteinpercentOfDailyNeed', 'FiberAmount', 'FiberpercentOfDailyNeed',
#        'VitaminB6Amount', 'VitaminB6percentOfDailyNeed', 'ManganeseAmount',
#        'ManganesepercentOfDailyNeed', 'SeleniumAmount',
#        'SeleniumpercentOfDailyNeed', 'PotassiumAmount',
#        'PotassiumpercentOfDailyNeed', 'VitaminB2Amount',
#        'VitaminB2percentOfDailyNeed', 'VitaminCAmount',
#        'VitaminCpercentOfDailyNeed', 'PhosphorusAmount',
#        'PhosphoruspercentOfDailyNeed', 'FolateAmount',
#        'FolatepercentOfDailyNeed', 'VitaminB5Amount',
#        'VitaminB5percentOfDailyNeed', 'MagnesiumAmount',
#        'MagnesiumpercentOfDailyNeed', 'IronAmount', 'IronpercentOfDailyNeed',
#        'VitaminKAmount', 'VitaminKpercentOfDailyNeed', 'CopperAmount',
#        'CopperpercentOfDailyNeed', 'VitaminAAmount',
#        'VitaminApercentOfDailyNeed', 'VitaminB12Amount',
#        'VitaminB12percentOfDailyNeed', 'VitaminDAmount',
#        'VitaminDpercentOfDailyNeed', 'ZincAmount', 'ZincpercentOfDailyNeed',
#        'VitaminEAmount', 'VitaminEpercentOfDailyNeed', 'VitaminB3Amount',
#        'VitaminB3percentOfDailyNeed', 'VitaminB1Amount',
#        'VitaminB1percentOfDailyNeed', 'CalciumAmount',
#        'CalciumpercentOfDailyNeed', 'AlcoholAmount',
#        'AlcoholpercentOfDailyNeed', 'CaffeineAmount',
#        'CaffeinepercentOfDailyNeed'],
#       dtype='object')

# %% [markdown]
# #### Rename column id to RecipeId. Drop column "veryHealthy".

# %%
new_df.rename(columns = {'column':'RecipeId'}, inplace = True) ### here you are renaming a column called "column" into "RecipeId" instead of renaming "Id"
new_df
# Out:
#             Unnamed: 0  glutenFree  dairyFree  veryHealthy  healthScore  \
# vegetarian
# True                 0        True       True        False          1.0
# True                 1        True      False        False          0.0
# False                2       False      False        False          3.0
# True                 3       False       True        False          2.0
# False                4        True      False        False         31.0
# ...                ...         ...        ...          ...          ...
# False              145        True       True        False         18.0
# True               146       False      False        False          1.0
# True               147        True       True         True         93.0
# True               148        True      False        False          5.0
# True               149        True       True         True        100.0
#
#             aggregateLikes      id  \
# vegetarian
# True                     3  633998
# True                     1  634426
# False                    1  635085
# True                     1  663229
# False                    3  651437
# ...                    ...     ...
# False                   13  638315
# True                     2  656248
# True                     2  637297
# True                     1  659412
# True                     4  647875
#
#                                                         title  \
# vegetarian
# True                                Banana Blueberry Pancakes
# True                  Basil and Orange Confit Compound Butter
# False                                Black Bottom Banana Bars
# True                      The Best Raw Chocolate Chip Cookies
# False                     Mediterranean Spinach Artichoke Dip
# ...                                                       ...
# False            Chicken Sausage, White Bean and Cabbage Soup
# True                                      Pinot Noir Brownies
# True                                Cauliflower Chickpea Stew
# True        Sautéed Balsamic Green Beans With Cherry Tomatoes
# True              Indian-Style Dill and Turmeric Potato Salad
#
#             pricePerServing  readyInMinutes  ...  VitaminB3Amount  \
# vegetarian                                   ...
# True                  55.79              45  ...             0.49
# True                  15.07              45  ...              NaN
# False                 78.85              45  ...             2.63
# True                  54.64              45  ...             0.65
# False                115.26              45  ...             0.66
# ...                     ...             ...  ...              ...
# False                196.23              45  ...             0.53
# True                  65.76              45  ...             0.21
# True                 139.28              45  ...             4.77
# True                 101.81              45  ...             1.15
# True                 117.24              30  ...             0.21
#
#            VitaminB3percentOfDailyNeed  VitaminB1Amount  \
# vegetarian
# True                              2.44             0.03
# True                               NaN              NaN
# False                            13.13             0.32
# True                              3.26             0.10
# False                             3.29             0.07
# ...                                ...              ...
# False                             2.67             0.15
# True                              1.07             0.03
# True                             23.83             0.45
# True                              5.73             0.12
# True                              1.05              NaN
#
#             VitaminB1percentOfDailyNeed  CalciumAmount  \
# vegetarian
# True                               2.26          18.11
# True                                NaN            NaN
# False                             21.09         100.80
# True                               6.47          26.79
# False                              4.64         162.84
# ...                                 ...            ...
# False                             10.23         102.67
# True                               1.68          19.82
# True                              29.70         141.16
# True                               7.85          55.64
# True                                NaN          27.96
#
#             CalciumpercentOfDailyNeed  AlcoholAmount  \
# vegetarian
# True                             1.81            NaN
# True                              NaN            NaN
# False                           10.08           0.28
# True                             2.68            NaN
# False                           16.28            NaN
# ...                               ...            ...
# False                           10.27            NaN
# True                             1.98           2.48
# True                            14.12            NaN
# True                             5.56            NaN
# True                             2.80            NaN
#
#             AlcoholpercentOfDailyNeed  CaffeineAmount  \
# vegetarian
# True                              NaN             NaN
# True                              NaN             NaN
# False                            1.53            9.89
# True                              NaN             NaN
# False                             NaN             NaN
# ...                               ...             ...
# False                             NaN             NaN
# True                            13.76           10.69
# True                              NaN             NaN
# True                              NaN             NaN
# True                              NaN             NaN
#
#             CaffeinepercentOfDailyNeed
# vegetarian
# True                               NaN
# True                               NaN
# False                             3.30
# True                               NaN
# False                              NaN
# ...                                ...
# False                              NaN
# True                              3.56
# True                               NaN
# True                               NaN
# True                               NaN
#
# [150 rows x 78 columns]

# %%
new_df.drop("veryHealthy", axis=1, inplace=True) ### the error at the last line says "['veryHealthy'] not found in axis"  That means your axis argument is probably wrong. Did you try another axis?
newdf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12044/2467592028.py in <module>
# ----> 1 new_df.drop("veryHealthy", axis=1, inplace=True)
#       2 newdf
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['veryHealthy'] not found in axis"

# %% [markdown]
# #### Some questions to think of for yourself. Feel free to ask us if you are in doubt, we are open for a discussion! :)

# %% [markdown]
# 1. Are there any other columns in this dataset that you would consider a candidate for the index column? Why isn't is always a good idea to use a string as index?
# 2. Take a closer look at arguments "axis" and "inplace" in functions drop(...) and rename(...). Maybe google for documentation if you are not sure what they mean.
#         What happens if you wanted to rename a column that is not there?
#         What happens if you set the argument inplace=True?

# %% [markdown]
# #### Import pandas library using alias pd.

# %%
import pandas as pd

# %% [markdown]
# #### Load file recipes.csv from the data subfolder and store it in a variable df_ex1. Use the first column as index.

# %%
df = pd.read_csv("data/Recipes.csv")
df
df_ex1 = pd.read_csv("data/Recipes.csv", index_col=1) ### same indexing issue :)
df_ex1
# Out:
#             Unnamed: 0  glutenFree  dairyFree  veryHealthy  healthScore  \
# vegetarian
# True                 0        True       True        False          1.0
# True                 1        True      False        False          0.0
# False                2       False      False        False          3.0
# True                 3       False       True        False          2.0
# False                4        True      False        False         31.0
# ...                ...         ...        ...          ...          ...
# False              145        True       True        False         18.0
# True               146       False      False        False          1.0
# True               147        True       True         True         93.0
# True               148        True      False        False          5.0
# True               149        True       True         True        100.0
#
#             aggregateLikes      id  \
# vegetarian
# True                     3  633998
# True                     1  634426
# False                    1  635085
# True                     1  663229
# False                    3  651437
# ...                    ...     ...
# False                   13  638315
# True                     2  656248
# True                     2  637297
# True                     1  659412
# True                     4  647875
#
#                                                         title  \
# vegetarian
# True                                Banana Blueberry Pancakes
# True                  Basil and Orange Confit Compound Butter
# False                                Black Bottom Banana Bars
# True                      The Best Raw Chocolate Chip Cookies
# False                     Mediterranean Spinach Artichoke Dip
# ...                                                       ...
# False            Chicken Sausage, White Bean and Cabbage Soup
# True                                      Pinot Noir Brownies
# True                                Cauliflower Chickpea Stew
# True        Sautéed Balsamic Green Beans With Cherry Tomatoes
# True              Indian-Style Dill and Turmeric Potato Salad
#
#             pricePerServing  readyInMinutes  ...  VitaminB3Amount  \
# vegetarian                                   ...
# True                  55.79              45  ...             0.49
# True                  15.07              45  ...              NaN
# False                 78.85              45  ...             2.63
# True                  54.64              45  ...             0.65
# False                115.26              45  ...             0.66
# ...                     ...             ...  ...              ...
# False                196.23              45  ...             0.53
# True                  65.76              45  ...             0.21
# True                 139.28              45  ...             4.77
# True                 101.81              45  ...             1.15
# True                 117.24              30  ...             0.21
#
#            VitaminB3percentOfDailyNeed  VitaminB1Amount  \
# vegetarian
# True                              2.44             0.03
# True                               NaN              NaN
# False                            13.13             0.32
# True                              3.26             0.10
# False                             3.29             0.07
# ...                                ...              ...
# False                             2.67             0.15
# True                              1.07             0.03
# True                             23.83             0.45
# True                              5.73             0.12
# True                              1.05              NaN
#
#             VitaminB1percentOfDailyNeed  CalciumAmount  \
# vegetarian
# True                               2.26          18.11
# True                                NaN            NaN
# False                             21.09         100.80
# True                               6.47          26.79
# False                              4.64         162.84
# ...                                 ...            ...
# False                             10.23         102.67
# True                               1.68          19.82
# True                              29.70         141.16
# True                               7.85          55.64
# True                                NaN          27.96
#
#             CalciumpercentOfDailyNeed  AlcoholAmount  \
# vegetarian
# True                             1.81            NaN
# True                              NaN            NaN
# False                           10.08           0.28
# True                             2.68            NaN
# False                           16.28            NaN
# ...                               ...            ...
# False                           10.27            NaN
# True                             1.98           2.48
# True                            14.12            NaN
# True                             5.56            NaN
# True                             2.80            NaN
#
#             AlcoholpercentOfDailyNeed  CaffeineAmount  \
# vegetarian
# True                              NaN             NaN
# True                              NaN             NaN
# False                            1.53            9.89
# True                              NaN             NaN
# False                             NaN             NaN
# ...                               ...             ...
# False                             NaN             NaN
# True                            13.76           10.69
# True                              NaN             NaN
# True                              NaN             NaN
# True                              NaN             NaN
#
#             CaffeinepercentOfDailyNeed
# vegetarian
# True                               NaN
# True                               NaN
# False                             3.30
# True                               NaN
# False                              NaN
# ...                                ...
# False                              NaN
# True                              3.56
# True                               NaN
# True                               NaN
# True                               NaN
#
# [150 rows x 78 columns]

# %%
df_ex1.rename(columns = {'Unnamed: 0':'name'}, inplace = True) ### it was unnamed because it was supposed to be the index :) 
df_ex1 #changed the name for the unnamed as 0 was confusing
# Out:
#             name  glutenFree  dairyFree  veryHealthy  healthScore  \
# vegetarian
# True           0        True       True        False          1.0
# True           1        True      False        False          0.0
# False          2       False      False        False          3.0
# True           3       False       True        False          2.0
# False          4        True      False        False         31.0
# ...          ...         ...        ...          ...          ...
# False        145        True       True        False         18.0
# True         146       False      False        False          1.0
# True         147        True       True         True         93.0
# True         148        True      False        False          5.0
# True         149        True       True         True        100.0
#
#             aggregateLikes      id  \
# vegetarian
# True                     3  633998
# True                     1  634426
# False                    1  635085
# True                     1  663229
# False                    3  651437
# ...                    ...     ...
# False                   13  638315
# True                     2  656248
# True                     2  637297
# True                     1  659412
# True                     4  647875
#
#                                                         title  \
# vegetarian
# True                                Banana Blueberry Pancakes
# True                  Basil and Orange Confit Compound Butter
# False                                Black Bottom Banana Bars
# True                      The Best Raw Chocolate Chip Cookies
# False                     Mediterranean Spinach Artichoke Dip
# ...                                                       ...
# False            Chicken Sausage, White Bean and Cabbage Soup
# True                                      Pinot Noir Brownies
# True                                Cauliflower Chickpea Stew
# True        Sautéed Balsamic Green Beans With Cherry Tomatoes
# True              Indian-Style Dill and Turmeric Potato Salad
#
#             pricePerServing  readyInMinutes  ...  VitaminB3Amount  \
# vegetarian                                   ...
# True                  55.79              45  ...             0.49
# True                  15.07              45  ...              NaN
# False                 78.85              45  ...             2.63
# True                  54.64              45  ...             0.65
# False                115.26              45  ...             0.66
# ...                     ...             ...  ...              ...
# False                196.23              45  ...             0.53
# True                  65.76              45  ...             0.21
# True                 139.28              45  ...             4.77
# True                 101.81              45  ...             1.15
# True                 117.24              30  ...             0.21
#
#            VitaminB3percentOfDailyNeed  VitaminB1Amount  \
# vegetarian
# True                              2.44             0.03
# True                               NaN              NaN
# False                            13.13             0.32
# True                              3.26             0.10
# False                             3.29             0.07
# ...                                ...              ...
# False                             2.67             0.15
# True                              1.07             0.03
# True                             23.83             0.45
# True                              5.73             0.12
# True                              1.05              NaN
#
#             VitaminB1percentOfDailyNeed  CalciumAmount  \
# vegetarian
# True                               2.26          18.11
# True                                NaN            NaN
# False                             21.09         100.80
# True                               6.47          26.79
# False                              4.64         162.84
# ...                                 ...            ...
# False                             10.23         102.67
# True                               1.68          19.82
# True                              29.70         141.16
# True                               7.85          55.64
# True                                NaN          27.96
#
#             CalciumpercentOfDailyNeed  AlcoholAmount  \
# vegetarian
# True                             1.81            NaN
# True                              NaN            NaN
# False                           10.08           0.28
# True                             2.68            NaN
# False                           16.28            NaN
# ...                               ...            ...
# False                           10.27            NaN
# True                             1.98           2.48
# True                            14.12            NaN
# True                             5.56            NaN
# True                             2.80            NaN
#
#             AlcoholpercentOfDailyNeed  CaffeineAmount  \
# vegetarian
# True                              NaN             NaN
# True                              NaN             NaN
# False                            1.53            9.89
# True                              NaN             NaN
# False                             NaN             NaN
# ...                               ...             ...
# False                             NaN             NaN
# True                            13.76           10.69
# True                              NaN             NaN
# True                              NaN             NaN
# True                              NaN             NaN
#
#             CaffeinepercentOfDailyNeed
# vegetarian
# True                               NaN
# True                               NaN
# False                             3.30
# True                               NaN
# False                              NaN
# ...                                ...
# False                              NaN
# True                              3.56
# True                               NaN
# True                               NaN
# True                               NaN
#
# [150 rows x 78 columns]

# %% [markdown]
# #### See if the 34th recipe on the list is vegetarian (remember the 0-based indexing!). Please do this in 4 different ways. Be careful with how .iloc and .loc handle things.

# %%
df_ex1.iloc[33, 7] #i dont understand how to reach column "vegetarian". when i put 0 instead of 8, it refers to the name.

### That's because you used the vegetarian column as an index. You can't access an index like a normal cell in the table.
### If you use the right index, this will be easier :)
# Out:
# 'Detox Orange Carrot Juice'

# %%
df_ex1['title'][0] #why does it go through the whole df and does not choose the raw i asked to choose?


### That's because your index is not numbers. If you check the table above, you see the first column being the index column which is "vegetarian"
### That means your index is "True" and "False" values, which is not a good index to have. 
### I can see most of your issues with the exercises are due to you choosing the wrong index column :)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lw/nvvclwgj78n7ns07pq1cr33m0000gn/T/ipykernel_59402/1494674668.py in <module>
# ----> 1 df_ex1['title'][0] #why does it go through the whole df and does not choose the raw i asked to choose?
#       2
#       3
#       4 ### That's because your index is not numbers. If you check the table above, you see the first column being the index column which is "vegetarian"
#       5 ### That means your index is "True" and "False" values, which is not a good index to have.
#
# NameError: name 'df_ex1' is not defined

# %% [markdown]
# #### Choose columns with the following info and in the following order: title, price and if it is vegetarian

# %%
df_ex1[['title', 'pricePerServing']] #i did not put vege but it is still there

### again, it's because you used the vegetarian as your index. Index will always show
# Out:
#                                                         title  pricePerServing
# vegetarian
# True                                Banana Blueberry Pancakes            55.79
# True                  Basil and Orange Confit Compound Butter            15.07
# False                                Black Bottom Banana Bars            78.85
# True                      The Best Raw Chocolate Chip Cookies            54.64
# False                     Mediterranean Spinach Artichoke Dip           115.26
# ...                                                       ...              ...
# False            Chicken Sausage, White Bean and Cabbage Soup           196.23
# True                                      Pinot Noir Brownies            65.76
# True                                Cauliflower Chickpea Stew           139.28
# True        Sautéed Balsamic Green Beans With Cherry Tomatoes           101.81
# True              Indian-Style Dill and Turmeric Potato Salad           117.24
#
# [150 rows x 2 columns]

# %% [markdown]
# #### And now the same for recipes number from 24 to 29

# %%
df_ex1.iloc[24 : 30, 7 : 9]
# Out:
#                                     title  pricePerServing
# vegetarian
# True        Green Beans with Garlic Chips            83.90
# False          Pandan Thumbprint Biscuits            54.26
# False                       Lamb Moussaka           528.50
# True               Easy Eggplant Parmesan           195.51
# True                            Peach Pie           173.52
# True                           Kappa Maki            72.94

# %% [markdown]
# #### Play with some slicing and accesing. Do you understand the result that you obtain from different trials? Please feel free to ask us about what you see! :)

# %%
df_ex1.iloc[[1, 2, 3],:]
# Out:
#             name  glutenFree  dairyFree  veryHealthy  healthScore  \
# vegetarian
# True           1        True      False        False          0.0
# False          2       False      False        False          3.0
# True           3       False       True        False          2.0
#
#             aggregateLikes      id                                    title  \
# vegetarian
# True                     1  634426  Basil and Orange Confit Compound Butter
# False                    1  635085                 Black Bottom Banana Bars
# True                     1  663229      The Best Raw Chocolate Chip Cookies
#
#             pricePerServing  readyInMinutes  ...  VitaminB3Amount  \
# vegetarian                                   ...
# True                  15.07              45  ...              NaN
# False                 78.85              45  ...             2.63
# True                  54.64              45  ...             0.65
#
#            VitaminB3percentOfDailyNeed  VitaminB1Amount  \
# vegetarian
# True                               NaN              NaN
# False                            13.13             0.32
# True                              3.26             0.10
#
#             VitaminB1percentOfDailyNeed  CalciumAmount  \
# vegetarian
# True                                NaN            NaN
# False                             21.09         100.80
# True                               6.47          26.79
#
#             CalciumpercentOfDailyNeed  AlcoholAmount  \
# vegetarian
# True                              NaN            NaN
# False                           10.08           0.28
# True                             2.68            NaN
#
#             AlcoholpercentOfDailyNeed  CaffeineAmount  \
# vegetarian
# True                              NaN             NaN
# False                            1.53            9.89
# True                              NaN             NaN
#
#             CaffeinepercentOfDailyNeed
# vegetarian
# True                               NaN
# False                              3.3
# True                               NaN
#
# [3 rows x 78 columns]

# %% [markdown]
# #### Notice which slicing methods are inclusive and which of them are exclusive. Try to figure your favourite way of accesing / slicing and remember that sometimes some of them make more sense than the others.

# %%
df_ex1[20:40] #raws
# Out:
#             name  glutenFree  dairyFree  veryHealthy  healthScore  \
# vegetarian
# True          20        True       True        False         20.0
# False         21       False      False        False         21.0
# True          22        True      False        False         16.0
# True          23       False      False        False          9.0
# True          24        True      False        False          6.0
# False         25       False      False        False          0.0
# False         26       False      False        False         42.0
# True          27        True      False        False         19.0
# True          28       False      False        False          3.0
# True          29        True       True        False         19.0
# True          30        True       True        False         17.0
# True          31        True      False        False          5.0
# False         32        True       True        False          6.0
# True          33        True       True        False         54.0
# False         34        True      False         True         78.0
# False         35        True      False        False          9.0
# False         36       False      False         True         57.0
# True          37        True      False        False         17.0
# True          38       False      False        False          9.0
# True          39        True       True        False          7.0
#
#             aggregateLikes       id  \
# vegetarian
# True                     1   642892
# False                   18   632874
# True                     1   636600
# True                     1   635447
# True                     7   645416
# False                    1   654516
# False                    1   649225
# True                     2   641962
# True                     7   655145
# True                     1   648742
# True                     1  1096306
# True                   249   716421
# False                    1   652758
# True                     2   641443
# False                   15   661340
# False                    6   634605
# False                    1   647124
# True                     1   658495
# True                     1   649300
# True                     6  1098357
#
#                                                         title  \
# vegetarian
# True                              Fire Roasted Tomato Chutney
# False       Asian Salmon Burgers With Tangy Ginger Lime Sauce
# True                                    Butternut Squash Soup
# True        Blueberry Compote Bread Pudding With Soft Curd...
# True                            Green Beans with Garlic Chips
# False                              Pandan Thumbprint Biscuits
# False                                           Lamb Moussaka
# True                                   Easy Eggplant Parmesan
# True                                                Peach Pie
# True                                               Kappa Maki
# True                                 Vegan Chana Masala Curry
# True        Grilled Peach Melba with Vanilla Bean Frozen Y...
# False                                        Mussels Marinara
# True                                Detox Orange Carrot Juice
# False               Spinach Salad with Strawberry Vinaigrette
# False                                        Beef Cottage Pie
# False              Homemade Thin Crust Pizza + Pesto + Potato
# True                         Roasted Asparagus with Egg Salad
# True        Latkes; Fried Vegetable Pancakes from Europe a...
# True                      Three Ingredient Frozen Pina Colada
#
#             pricePerServing  readyInMinutes  ...  VitaminB3Amount  \
# vegetarian                                   ...
# True                  74.69              45  ...             0.90
# False                370.04              30  ...            11.22
# True                 102.10              45  ...             3.57
# True                 270.38              45  ...             0.59
# True                  83.90              45  ...             1.28
# False                 54.26              45  ...             0.57
# False                528.50              45  ...            30.58
# True                 195.51              45  ...             2.02
# True                 173.52              45  ...             1.68
# True                  72.94              45  ...             2.03
# True                 165.89              30  ...             2.14
# True                 405.52              45  ...             1.33
# False                125.90              45  ...             0.90
# True                 104.27              45  ...             2.65
# False                338.97              45  ...             6.03
# False                113.45              45  ...             3.31
# False                199.57              45  ...             7.12
# True                 217.78              45  ...             2.17
# True                  58.55              45  ...             2.20
# True                 214.60               5  ...             1.05
#
#            VitaminB3percentOfDailyNeed  VitaminB1Amount  \
# vegetarian
# True                              4.50             0.06
# False                            56.10             0.54
# True                             17.83             0.20
# True                              2.97             0.27
# True                              6.42             0.15
# False                             2.87             0.06
# False                           152.90             0.46
# True                             10.12             0.10
# True                              8.41             0.16
# True                             10.15             0.19
# True                             10.71             0.20
# True                              6.63             0.07
# False                             4.52             0.06
# True                             13.26             0.35
# False                            30.15             0.19
# False                            16.55             0.05
# False                            35.59             1.12
# True                             10.85             0.23
# True                             10.98             0.27
# True                              5.25             0.19
#
#             VitaminB1percentOfDailyNeed  CalciumAmount  \
# vegetarian
# True                               3.71          34.28
# False                             36.17         102.05
# True                              13.23          91.18
# True                              18.00         613.26
# True                              10.04          73.38
# False                              3.83            NaN
# False                             30.62         478.31
# True                               6.86         156.77
# True                              10.93         116.78
# True                              12.73          21.56
# True                              13.09         154.27
# True                               4.70         184.10
# False                              4.19          41.74
# True                              23.48         168.53
# False                             12.65         221.46
# False                              3.33          45.50
# False                             74.83         201.23
# True                              15.32         150.39
# True                              17.86          56.43
# True                              12.66          52.87
#
#             CalciumpercentOfDailyNeed  AlcoholAmount  \
# vegetarian
# True                             3.43            NaN
# False                           10.20            NaN
# True                             9.12            NaN
# True                            61.33            NaN
# True                             7.34            NaN
# False                             NaN            NaN
# False                           47.83           1.05
# True                            15.68            NaN
# True                            11.68           0.75
# True                             2.16            NaN
# True                            15.43            NaN
# True                            18.41            NaN
# False                            4.17           6.18
# True                            16.85            NaN
# False                           22.15            NaN
# False                            4.55            NaN
# False                           20.12            NaN
# True                            15.04            NaN
# True                             5.64            NaN
# True                             5.29          13.36
#
#             AlcoholpercentOfDailyNeed  CaffeineAmount  \
# vegetarian
# True                              NaN             NaN
# False                             NaN             NaN
# True                              NaN             NaN
# True                              NaN             NaN
# True                              NaN             NaN
# False                             NaN           18.48
# False                            5.83             NaN
# True                              NaN             NaN
# True                             4.14             NaN
# True                              NaN             NaN
# True                              NaN             NaN
# True                              NaN             NaN
# False                           34.33             NaN
# True                              NaN             NaN
# False                             NaN             NaN
# False                             NaN             NaN
# False                             NaN             NaN
# True                              NaN             NaN
# True                              NaN             NaN
# True                            74.22             NaN
#
#             CaffeinepercentOfDailyNeed
# vegetarian
# True                               NaN
# False                              NaN
# True                               NaN
# True                               NaN
# True                               NaN
# False                             6.16
# False                              NaN
# True                               NaN
# True                               NaN
# True                               NaN
# True                               NaN
# True                               NaN
# False                              NaN
# True                               NaN
# False                              NaN
# False                              NaN
# False                              NaN
# True                               NaN
# True                               NaN
# True                               NaN
#
# [20 rows x 78 columns]

# %% [markdown]
# ### Class-exercise 2

# %%
import numpy as np

# %% [markdown]
# 1. Create a 2-d and 3-d numpy integer array

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5, 10, 20]) 
b = np.array([[1, 2, 3], [5, 10, 20]]) #how many elements can be in each [] brackets? 
### As many as you want as long as the dimensions make sense as a matrix

print(a.ndim) 
print(b.ndim)
print(c.ndim)
# Out:
# 1
# 2
# 2

# %% [markdown]
# 2. Create a 2X2 integer array and show it's dimensions

# %%
b = np.array([[1, 2], [5, 10]])
print(b.ndim)
# Out:
# 2

# %% [markdown]
# 3. Create a numpy array and  print the sum of third and fourth elements from the array

# %%
a = np.array([1, 2, 3, 4, 5, 10, 20])
print(a[2] + a[3])
# Out:
# 7

# %%
b = np.array([[1, 2], [5, 10]])
print(b[0, 1] + b[1, 1])
# Out:
# 12

# %% [markdown]
# 4. Slice the below array to get the the second item to the excluding fifth item
#
# arr = np.array([10, 15, 20, 25, 30, 35, 40])

# %%
arr = np.array([10, 15, 20, 25, 30, 35, 40])
print(arr[1:5])
# Out:
# [15 20 25 30]

# %% [markdown]
# 5. Try example 4. using STEP method

# %%
print(arr[1:5:1])
# Out:
# [15 20 25 30]

# %% [markdown]
# 6. Create a integer array and change data type from integer to boolean

# %%
cat = np.array([0,1,0,1,2,3],dtype=bool)
newar = cat.astype('bool')
print(newar.dtype)
# Out:
# bool

# %% [markdown]
# 7. Use NumPy syntax to check the shape of an array.
#
# arr = np.array([1, 2, 3, 4, 5])

# %%
arr = np.array([1, 2, 3, 4, 5])
print(arr.shape)
# Out:
# (5,)

# %% [markdown]
# 8. Find the indexes where the values are even:
#
# arr = [16, 8, 3, 7, 15, 24]

# %%
arr = np.array([16, 8, 3, 7, 15, 24])
x = np.where(arr%2 == 0)
print(x)

### Do you understand the result here? You got the indices of the items you asked for
# Out:
# (array([0, 1, 5], dtype=int64),)

# %% [markdown]
# 9. Create a numpy array of 5 person names and sort the values alpbabetically

# %%
cat = np.array(['victoria', 'radhika', 'leo', 'rami', 'edit' ],dtype='S')
print(np.sort(cat)) #what is b?

### b is due to some encoding stuff. Try setting dtype to 'U' and see if it makes a difference. Read about type U too
# Out:
# [b'edit' b'leo' b'radhika' b'rami' b'victoria']

# %% [markdown]
# 10. Use the correct NumPy method to return a sorted array.
#
#   arr = np.array([3, 2, 0, 1])

# %%
arr = np.array([3, 2, 0, 1])
print(np.sort(arr))
# Out:
# [0 1 2 3]

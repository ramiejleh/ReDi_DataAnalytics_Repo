# %% [markdown]
# Clean the pension fund dataset!
# The dataset you're about to work with contains an excerpt of a much larger dataset with all the Danish pension funds' investments. It is provided as a CSV file with the following columns: name of the pension fund, name of the company, invested amount. The separator of the CSV file is the semicolon (;).
#
# Your task is to clean and format the data according to the guidelines below and then write it to a new (!) CSV file.
#
# Please note that the only module you will have to import is Python's built-in CSV module. Some of the tasks can be solved using other modules, but this is totally optional, and you will most probably be able to solve the tasks faster by implementing your own function instead of searching for a corresponding one (be aware that this only counts for this exercise - in other circumstances it may be much better to use existing modules!).
#
# In this exercise, you should focus on breaking the code into several helper functions. Work on making each of the helper functions return the desired output, which in turn involves looking at what exactly you provide as input to the function.
#
# Complete the following tasks - but think about the order in which you do them first!
#
# Remove any wrong or odd row entries.
# Read the file into memory.
# All the columns with the company names begin with 'company_name:'. Remove this, so that the entry only contains the company's name.
# Write the nice and clean data to another CSV file.
# In the raw file, the invested sums are formatted in different ways. AkademikerPension is formatted as decimal numbers, and Industriens Pension is in million DKK (e. g. 130 means 130000000). Only PenSam and Velliv are already formatted correctly. All of the sums have to be formatted as non-decimal numbers and as a complete number, e.g. if the investment is 5.9 million DKK, the entry should be 5900000 and nothing else.
# For the tasks involving string manipulation, you can find help here: https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/14-Strings-and-Regular-Expressions.ipynb
#
# If you are done with the tasks above, please do the following:
#
# Create a dictionary with the name of the pension fund as the key, and a list of lists as the value of each fund. The list should contain the largest invested sum in a single company and the median investment. It should be in the following format: [[company name (str), invested sum (int)], [company name (str), invested sum (int)]] with the entry at index 0 being the company where the corresponding pension fund has invested the largest amount of money.
# Make sure all your helper functions contain docstrings according to PEP8.

# %%
#Read the file into memory
import csv
filename = "pension_fund_data.csv"
with open(filename) as file:
    reader = csv.reader(file, delimiter = ';') #delimetiter seperated by camma from previous symbol
    header = next(reader)
    fund_data = []
    for row in reader:
        fund_data.append(row)
    print(type(fund_data))
print(header)
# Out:
# <class 'list'>
# ['pension_fund', 'company ', 'invested_amount']

# %%
# Remove any wrong or odd row entries
fund_name = list(set([row[0] for row in fund_data]))
print(fund_name)
# Out:
# ['PenSam', 'Velliv', 'Nofund', 'AkademikerPension', 'Industriens Pension']

# %%
def remove_bad_entries(dataset, string_to_remove): 
    dataset_new = []

    for row in dataset:
        if string_to_remove not in row:
            dataset_new.append(row)
    return dataset_new

fund_data = remove_bad_entries(fund_data, "Nofund")
    
print(fund_data)
# Out:
# [['AkademikerPension', 'company_name: ANDRITZ AG', '9035889.67000961'], ['AkademikerPension', 'company_name: Verbund AG', '535484.04264'], ['AkademikerPension', 'company_name: Wienerberger AG', '489278.539054215'], ['AkademikerPension', 'company_name: ams AG', '9582835.98899249'], ['AkademikerPension', 'company_name: Oesterreichische Post AG', '283768.092184449'], ['AkademikerPension', 'company_name: Pendal Group Ltd', '1279011.44099595'], ['AkademikerPension', 'company_name: Asaleo Care Ltd', '311739.24'], ['AkademikerPension', 'company_name: Aristocrat Leisure Ltd', '159265.740991766'], ['AkademikerPension', 'company_name: ALS Ltd', '10314327.76'], ['AkademikerPension', 'company_name: Altium Ltd', '14675679.27'], ['AkademikerPension', 'company_name: AMP Ltd', '210881.09'], ['AkademikerPension', 'company_name: AUST AND NZ BANKING GROUP', '15375.58598142'], ['AkademikerPension', 'company_name: Australia & New Zealand Banking Group Ltd', '723352.74'], ['AkademikerPension', 'company_name: Afterpay Ltd', '52173246.8698483'], ['AkademikerPension', 'company_name: ARB Corp Ltd', '1264033.30473119'], ['AkademikerPension', 'company_name: Aurizon Holdings Ltd', '464861.38'], ['AkademikerPension', 'company_name: BHP Group Ltd', '864932.15'], ['AkademikerPension', 'company_name: BlueScope Steel Ltd', '917444.99'], ['AkademikerPension', 'company_name: Brambles Ltd', '27064700.0083148'], ['AkademikerPension', 'company_name: carsales.com Ltd', '7762697.73'], ['AkademikerPension', 'company_name: Challenger Ltd', '102934.07'], ['AkademikerPension', 'company_name: Sungard AS New Holdings III LLC', '86069.3048419842'], ['AkademikerPension', 'company_name: Superior Energy Services Inc', '4876.30308519994'], ['AkademikerPension', 'company_name: a2 Milk Co Ltd/The', '3541279.4'], ['AkademikerPension', 'company_name: Fisher & Paykel Healthcare Corp Ltd', '20645924.7901157'], ['AkademikerPension', 'company_name: Fletcher Building Ltd', '416220.93'], ['AkademikerPension', 'company_name: SKY Network Television Ltd', '94699.0000000001'], ['AkademikerPension', 'company_name: Xero Ltd', '55058026.5397112'], ['AkademikerPension', 'company_name: Copa Holdings SA', '26475067.0386764'], ['AkademikerPension', 'company_name: Ayala Land Inc', '21203523.018685'], ['AkademikerPension', 'company_name: BANK OF THE PHILIPPINE ISLAN', '60200.1842401783'], ['AkademikerPension', 'company_name: Bank of the Philippine Islands', '8026691.23537698'], ['AkademikerPension', 'company_name: GT Capital Holdings Inc', '509884.860641693'], ['AkademikerPension', 'company_name: FIRST BANCORP PUERTO RICO', '23846.623908'], ['AkademikerPension', 'company_name: First BanCorp/Puerto Rico', '4841240.7'], ['AkademikerPension', 'company_name: Popular Inc', '4323906.8552835'], ['AkademikerPension', 'company_name: Jeronimo Martins SGPS SA', '486822.302129009'], ['AkademikerPension', 'company_name: Alrosa PJSC', '804648.459918326'], ['AkademikerPension', 'company_name: Sberbank of Russia PJSC', '19143639.6143176'], ['AkademikerPension', 'company_name: SKF AB', '13273406.6633907'], ['AkademikerPension', 'company_name: Telefonaktiebolaget LM Ericsson', '161110047.305397'], ['AkademikerPension', 'company_name: Skanska AB', '5239693.04'], ['AkademikerPension', 'company_name: Trelleborg AB', '6148926.74'], ['AkademikerPension', 'company_name: Volvo AB', '33971461.6960737'], ['AkademikerPension', 'company_name: SSAB AB', '3869236.51'], ['AkademikerPension', 'company_name: Skandinaviska Enskilda Banken AB', '40280221.8488569'], ['AkademikerPension', 'company_name: Getinge AB', '262223.69'], ['AkademikerPension', 'company_name: Modern Times Group MTG AB', '119935.100307132'], ['AkademikerPension', 'company_name: Sandvik AB', '20269610.1958841'], ['AkademikerPension', 'company_name: Cellavision AB', '2530996.36'], ['AkademikerPension', 'company_name: BillerudKorsnas AB', '5760095.79'], ['AkademikerPension', 'company_name: INVISIO AB', '4402581.34'], ['AkademikerPension', 'company_name: Fortnox AB', ' ...

# %%
company_name_list= set([row[1] for row in fund_data])
print(company_name_list)
# Out:
# {'company_name: IRONGATE GROUP', 'company_name: Jazz Securities DAC', 'company_name: Banque Cantonale Vaudoise', 'company_name: TIM SA', 'company_name: Assa Abloy AB', 'company_name: VPOWER GROUP INTERNATIONAL H', 'company_name: SPRINT SPECTRUM SPRNTS 4.738 03/20/25', 'company_name: PETRONAS DAGANGAN BHD', 'company_name: AVOLON HDGS AVOL 5.125 10/01/23', 'company_name: PERFECT WORLD CO LTD-A', 'company_name: JIANGSU YOKE TECHNOLOGY-A', 'company_name: Slack Technologies Inc', 'company_name: Portland General Electric Co', 'company_name: CARLSBERG AS-B', 'company_name: NAKED WINES PLC', 'company_name: NIKKISO CO LTD', 'company_name: Aristocrat Leisure Ltd', 'company_name: HT&E LTD', 'company_name: RenaissanceRe Holdings Ltd', 'company_name: KATO SANGYO CO LTD', 'company_name: BOMBARDIER INC-B', 'company_name: AEROVIRONMENT INC', 'company_name: BENEFIT ONE INC', 'company_name: DOWA HOLDINGS CO LTD', 'company_name: Ramsay Health Care Ltd', 'company_name: PATTERSON-UTI ENERGY INC', 'company_name: Remgro Ltd', 'company_name: ORGANON FIN 1 ORGNON 4.125 04/30/28', 'company_name: Tyson Foods Inc', 'company_name: TORONTO-DOMINION BANK', 'company_name: Sany Heavy Industry Co Ltd', 'company_name: Stifel Financial Corp', 'company_name: BOE Technology Group Co Ltd', 'company_name: KROGER CO', 'company_name: Energy Absolute PCL', 'company_name: SOFTWARE AG', 'company_name: COMPAGNIE DES ALPES', 'company_name: SANSHIN ELECTRONICS CO LTD', 'company_name: Arrowhead Pharmaceuticals Inc', 'company_name: Evolution Mining Ltd', 'company_name: OUTSOURCING INC', 'company_name: SHENZHEN ENERGY GROUP CO L-A', 'company_name: SICHUAN ROAD&BRIDGE CO LT-A', 'company_name: Localiza Rent a Car SA', 'company_name: HUANENG POWER INTL INC-A', 'company_name: NISHIMATSUYA CHAIN CO LTD', "company_name: Ollie's Bargain Outlet Holdings Inc", 'company_name: BANC OF CALIFORNIA INC', 'company_name: MasTec Inc', 'company_name: PRESSANCE CORP', 'company_name: PriceSmart Inc', 'company_name: Western Digital Corp', 'company_name: SELVAAG BOLIG ASA', 'company_name: JUPITER MINES LTD', 'company_name: PRIMO WATER CORP', 'company_name: FOMENTO ECONOMICO MEX-SP ADR', 'company_name: ORIGIN ENTERPRISES PLC', 'company_name: SIGA TECHNOLOGIES INC', 'company_name: Marvell Technology Inc', 'company_name: Cooperatieve Rabobank UA', 'company_name: ADVERUM BIOTECHNOLOGIES INC', 'company_name: FATTAL HOLDINGS 1998 LTD', 'company_name: COLOPLAST-B', 'company_name: ADLER GROUP SA', 'company_name: SEIKO HOLDINGS CORP', 'company_name: GLP CAP/FIN II GLPI 5.3 01/15/29', 'company_name: Starbucks Corp', 'company_name: TESCO CORP TREAS TSCOLN 0.375 07/27/29', 'company_name: MARSH & MCLENNAN MMC 3.75 03/14/26', 'company_name: SANTEN PHARMACEUTICAL CO LTD', 'company_name: GAN LTD', 'company_name: YODOGAWA STEEL WORKS LTD', 'company_name: SPIRIT AEROSYSTE SPR 3.85 06/15/26', 'company_name: CREDICORP LTD', 'company_name: Y-mAbs Therapeutics Inc', 'company_name: Insurance Australia Group Ltd', 'company_name: Singapore Land Group Ltd', 'company_name: GLOBANT SA', 'company_name: SHENZHEN SALUBRIS PHARM-A', 'company_name: PHIBRO ANIMAL HEALTH CORP-A', 'company_name: Comision Federal de Electricidad', 'company_name: ARCLAND SAKAMOTO CO LTD', 'company_name: Grand Canyon Education Inc', 'company_name: AKATSUKI INC', 'company_name: BHP Group Ltd', 'company_name: SAF-HOLLAND SE', 'company_name: PORTO SEGURO SA', 'company_name: METRO PACIFIC INVESTMENTS CO', 'company_name: Brazil Capital Growth Part III B', 'company_name: TENCENT HOLDINGS TENCNT 3.975 04/11/29', 'company_name: TOTAL PRODUCE PLC', 'company_name: DAVIDE CAMPARI-MILANO NV', 'company_name: MODINE MANUFACTURING CO', 'company_name: CALIFORNIA RESOURCES CORP', 'company_name: United Overseas Bank Ltd', 'company_name: FOUNDER SECURITIES CO LTD-A', 'company_name: Electronic Arts Inc', 'company_name: ALPHA SYSTEMS INC', "company_name: LOWE'S COS INC", 'company_name: CARMILA', 'company_name: TATSUTA ELEC WIRE & CABLE', 'company_name: ANEST IWATA CORP', 'c ...

# %%
# remove repeated string from list from specific location
string_args = [row[1] for row in fund_data]
def r_string(string_args):
    string_args=string_args.replace("company_name:","")
    return string_args

   
for row in fund_data:
    row[1]=r_string(row[1])
    if row[0] == 'AkademikerPension':
        row[2] = round(float(row[2]))
    elif row[0] == 'Industriens Pension':
        row[2] = int(float(row[2])*1000000)
        
   # print(row[0], row[1], row[2])
    
print(fund_data)
# Out:
# [['AkademikerPension', ' ANDRITZ AG', 9035890], ['AkademikerPension', ' Verbund AG', 535484], ['AkademikerPension', ' Wienerberger AG', 489279], ['AkademikerPension', ' ams AG', 9582836], ['AkademikerPension', ' Oesterreichische Post AG', 283768], ['AkademikerPension', ' Pendal Group Ltd', 1279011], ['AkademikerPension', ' Asaleo Care Ltd', 311739], ['AkademikerPension', ' Aristocrat Leisure Ltd', 159266], ['AkademikerPension', ' ALS Ltd', 10314328], ['AkademikerPension', ' Altium Ltd', 14675679], ['AkademikerPension', ' AMP Ltd', 210881], ['AkademikerPension', ' AUST AND NZ BANKING GROUP', 15376], ['AkademikerPension', ' Australia & New Zealand Banking Group Ltd', 723353], ['AkademikerPension', ' Afterpay Ltd', 52173247], ['AkademikerPension', ' ARB Corp Ltd', 1264033], ['AkademikerPension', ' Aurizon Holdings Ltd', 464861], ['AkademikerPension', ' BHP Group Ltd', 864932], ['AkademikerPension', ' BlueScope Steel Ltd', 917445], ['AkademikerPension', ' Brambles Ltd', 27064700], ['AkademikerPension', ' carsales.com Ltd', 7762698], ['AkademikerPension', ' Challenger Ltd', 102934], ['AkademikerPension', ' Sungard AS New Holdings III LLC', 86069], ['AkademikerPension', ' Superior Energy Services Inc', 4876], ['AkademikerPension', ' a2 Milk Co Ltd/The', 3541279], ['AkademikerPension', ' Fisher & Paykel Healthcare Corp Ltd', 20645925], ['AkademikerPension', ' Fletcher Building Ltd', 416221], ['AkademikerPension', ' SKY Network Television Ltd', 94699], ['AkademikerPension', ' Xero Ltd', 55058027], ['AkademikerPension', ' Copa Holdings SA', 26475067], ['AkademikerPension', ' Ayala Land Inc', 21203523], ['AkademikerPension', ' BANK OF THE PHILIPPINE ISLAN', 60200], ['AkademikerPension', ' Bank of the Philippine Islands', 8026691], ['AkademikerPension', ' GT Capital Holdings Inc', 509885], ['AkademikerPension', ' FIRST BANCORP PUERTO RICO', 23847], ['AkademikerPension', ' First BanCorp/Puerto Rico', 4841241], ['AkademikerPension', ' Popular Inc', 4323907], ['AkademikerPension', ' Jeronimo Martins SGPS SA', 486822], ['AkademikerPension', ' Alrosa PJSC', 804648], ['AkademikerPension', ' Sberbank of Russia PJSC', 19143640], ['AkademikerPension', ' SKF AB', 13273407], ['AkademikerPension', ' Telefonaktiebolaget LM Ericsson', 161110047], ['AkademikerPension', ' Skanska AB', 5239693], ['AkademikerPension', ' Trelleborg AB', 6148927], ['AkademikerPension', ' Volvo AB', 33971462], ['AkademikerPension', ' SSAB AB', 3869237], ['AkademikerPension', ' Skandinaviska Enskilda Banken AB', 40280222], ['AkademikerPension', ' Getinge AB', 262224], ['AkademikerPension', ' Modern Times Group MTG AB', 119935], ['AkademikerPension', ' Sandvik AB', 20269610], ['AkademikerPension', ' Cellavision AB', 2530996], ['AkademikerPension', ' BillerudKorsnas AB', 5760096], ['AkademikerPension', ' INVISIO AB', 4402581], ['AkademikerPension', ' Fortnox AB', 2416749], ['AkademikerPension', ' Genovis AB', 3483834], ['AkademikerPension', ' Xvivo Perfusion AB', 4466050], ['AkademikerPension', ' Inwido AB', 6752577], ['AkademikerPension', ' Assa Abloy AB', 1388917], ['AkademikerPension', ' Svenska Handelsbanken AB', 3356745], ['AkademikerPension', ' MIPS AB', 11311640], ['AkademikerPension', ' Boozt AB', 29385069], ['AkademikerPension', ' Essity AB', 30398980], ['AkademikerPension', ' Arjo AB', 11028859], ['AkademikerPension', ' BHG Group AB', 3301044], ['AkademikerPension', ' Atlas Copco AB', 91465322], ['AkademikerPension', ' Nordic Entertainment Group AB', 307669], ['AkademikerPension', ' Avanza Bank Holding AB', 9177345], ['AkademikerPension', ' Evolution AB', 18188105], ['AkademikerPension', ' CELLINK AB', 6934256], ['AkademikerPension', ' Sweco AB', 4264554], ['AkademikerPension', ' Epiroc AB', 7803833], ['AkademikerPension', ' Epiroc AB', 124520], ['AkademikerPension', ' Boliden AB', 44836059], ['AkademikerPension', ' Boliden AB', 798533], ['AkademikerPension', ' Investor AB', 21649734], ['AkademikerPension', ' Hexagon AB', 37652365], ['AkademikerPension', ' Nibe Indust ...

# %%
pention_fund = set([row[2] for row in fund_data])
print(pention_fund)
# Out:
# {'99', '41401637.7282384', '1214859.67998715', '2462256.15448439', '70896865.7784309', '228', '2575452', '283680', '107568', '1572036.52295312', '7287712.068702', '950954', '20728', '180037', '936796', '6209677.13', '25249987.349135', '194732', '264680', '1086078', '10918509.108118', '17768178', '984983', '11886384.8630171', '25580681.461734', '18181718.8803729', '3369865.14726398', '1552800.00035568', '197923', '1316589.74', '177070', '14466238.713015', '2743583', '4587953', '837933.78', '489278.539054215', '64075783.0329627', '1134815', '1017858', '285624', '264', '205388', '2752379.15', '196933', '16516258', '1159297', '152798', '78249', '5355', '227761504.583751', '12252378.08', '240178', '1106421', '243876', '6839897.090625', '216006', '15162393.83834', '198070', '11864735.0009311', '2348192.00454553', '988868.32', '1982239', '279131', '9810855.49275', '2290009.013936', '2904354.05326439', '9261266.434905', '8309575', '917188.66', '3335213.77513365', '94604440', '7031681.55', '93208724', '84445527', '1142678', '15644243.1369053', '300165', '280159', '24009857', '238967', '119550', '243568', '105027980.615922', '3888738.30387438', '53', '2644213', '1013771', '213769', '916145', '975197', '313880', '20319155', '3178841.42268329', '131647', '4861822', '21467206.557052', '295344', '1098407', '173256', '1202649', '240095.74441413', '2455531', '1107307', '307061', '2342063', '307562', '224420', '975', '6718376', '7516309', '87104691', '209000', '763057.41', '229621', '193411', '43316889.2066652', '118637361', '4561693', '73124', '938447', '14326168.6320425', '7914086', '964280', '289146', '288838', '82679', '1012065', '117431', '248223.568749156', '461', '1923265', '74361755.3157975', '321300236', '307254', '191027', '316', '95019713', '2063906.19', '1429872.83', '69118142.429362', '10715893.2775428', '2504420.05987058', '2684875', '239407', '1075830', '1113408', '180307', '283405', '254815.99', '6975847.54042809', '322356', '1445126', '279938', '75055571', '70925566.3625858', '91476280', '245841', '306714', '247190', '134305', '190954', '3575042.723118', '1001466.23', '8049638.66665352', '771580', '296591', '2829764.98', '102842974', '143706', '208663', '317040728', '585058.13', '84354193', '2476670.294343', '66427043', '4514770', '132572', '148155544', '91617', '3910797.59085577', '1034298', '34792942', '192678', '11817542.6889729', '7440131.5127505', '310952', '232126', '2120161', '9344874.12544735', '1964122.143933', '3570497', '321085', '264180', '203993001.507748', '4176194.57595', '1012800', '267879', '193105.280146769', '5648833.86980007', '1120393', '251543', '95701', '2576944.3794705', '3188883', '528', '1083150', '240293', '14293768.586437', '7152631', '194658', '137079', '75822294', '1185209', '4161099', '221', '309649', '6280645.875', '135924', '1581028.5603924', '82260007', '2585400', '65496', '1046642', '291529', '134113', '237982', '177533', '1099563', '9844427.783486', '274106', '75089', '3639680', '155649', '314265', '375824429', '278838', '220645', '92850', '10666795.66', '77', '281671', '4580388.3546', '2166576.47', '6762196.16756675', '96692097', '286796', '85992', '108412', '6028859.97417749', '83912', '40280221.8488569', '2177066', '4307556', '40', '1052814', '190991', '69', '11373937.745949', '2692552', '1987889.2', '3387365', '1033528', '75', '1011763', '208963', '308659', '998660', '31707991.0819377', '567417.58', '414370.55', '59', '81870', '2991647.85', '3123113.54', '4532843.409105', '3292900.82986865', '1096609', '199168930.150389', '111', '160119', '103137', '274326', '189230', '1119096', '1213254.72', '9894.49903772038', '79371629', '110380', '77439', '188093', '19391183', '982242', '221875', '386592.460293828', '578', '105140', '2753274.318402', '3810612.334298', '163547', '239947', '189823', '19624055.1007925', '69310', '8158929.63866435', '230238', '2.78', '21696049', '4256329', '111670548', '49673497.5706579', '446808.49', '43904345.7399091', '136810', '310104', '10962661', '225345', '112961' ...

# %%
# write the data into another CSV file
with open('output_file.csv','w', newline='\n') as newfile:
    new_writing_file = csv.writer(newfile)
    new_writing_file.writerow(header)
    for row in fund_data:
        new_writing_file.writerow(row)

# %% [markdown]
# # Clean the pension fund dataset!
#
# The dataset you're about to work with contains an excerpt of a much larger dataset with all the Danish pension funds' investments. It is provided as a CSV file with the following columns: name of the pension fund, name of the company, invested amount. The separator of the CSV file is the semicolon (;).
#
# Your task is to clean and format the data according to the guidelines below and then write it to a new (!) CSV file.
#
# Please note that the only module you will have to import is Python's built-in CSV module. Some of the tasks can be solved using other modules, but this is totally optional, and you will most probably be able to solve the tasks faster by implementing your own function instead of searching for a corresponding one (be aware that this only counts for this exercise - in other circumstances it may be much better to use existing modules!).
#
# In this exercise, you should focus on breaking the code into several helper functions. Work on making each of the helper functions return the desired output, which in turn involves looking at what exactly you provide as input to the function.
#
# Complete the following tasks - but think about the order in which you do them first!
#
# - Remove any wrong or odd row entries.
# - Read the file into memory.
# - All the columns with the company names begin with 'company_name:'. Remove this, so that the entry only contains the company's name.
# - Write the nice and clean data to another CSV file.
# - In the raw file, the invested sums are formatted in different ways. AkademikerPension is formatted as decimal numbers, and Industriens Pension is in million DKK (e. g. 130 means 130000000). Only PenSam and Velliv are already formatted correctly. All of the sums have to be formatted as non-decimal numbers and as a complete number, e.g. if the investment is 5.9 million DKK, the entry should be 5900000 and nothing else.
#
# For the tasks involving string manipulation, you can find help here: https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/14-Strings-and-Regular-Expressions.ipynb
#
# If you are done with the tasks above, please do the following:
# - Create a dictionary with the name of the pension fund as the key, and a list of lists as the value of each fund. The list should contain the largest invested sum in a single company and the median investment. It should be in the following format: [[company name (str), invested sum (int)], [company name (str), invested sum (int)]] with the entry at index 0 being the company where the corresponding pension fund has invested the largest amount of money.
# - Make sure all your helper functions contain docstrings according to PEP8.

# %%
import csv

filename = 'pension_fund_data.csv'
with open(filename) as file:
    reader = csv.reader(file, delimiter=';')
    header_row = next(reader)
    fund_data = []
    for row in reader:
        fund_data.append(row)
    print(type(fund_data))
# Out:
# <class 'list'>

# %%
fund_names =set([row[0] for row in fund_data]) #set function will not allow duplicates
print(fund_names)
# Out:
# {'AkademikerPension', 'Velliv', 'Nofund', 'Industriens Pension', 'PenSam'}

# %%
company_names = set([row[1] for row in fund_data])
def remove_company_name(company_cell):
    company_cell.replace('company_name: ', '')
print(company_names)
# Out:
# {'company_name: NOMURA HOLDINGS NOMURA 1.851 07/16/25', 'company_name: JIANGSU YUYUE MEDICAL EQU-A', 'company_name: HUMANWELL HEALTHCARE GROUP-A', 'company_name: INVINCIBLE INVESTMENT CORP', 'company_name: COMTURE CORP', 'company_name: DIGI INTERNATIONAL INC', 'company_name: MARUZEN SHOWA UNYU CO LTD', 'company_name: BRENNTAG AG', 'company_name: Starbucks Corp', 'company_name: SEIKAGAKU CORP', 'company_name: Goldman Sachs Group Inc/The', 'company_name: GALP ENERGIA SGPS SA', 'company_name: PACK CORP/THE', 'company_name: M&A CAPITAL PARTNERS CO LTD', 'company_name: Kennametal Inc', 'company_name: SUN FRONTIER FUDOUSAN CO LTD', 'company_name: BACARDI LTD BACARD 2.75 07/03/23', 'company_name: INDUSTRIAL & INFRASTRUCTURE', 'company_name: CARLSBERG AS-B', 'company_name: CHINA PETROLEUM & CHEMICAL-A', 'company_name: FLAT GLASS GROUP CO LTD-A', 'company_name: LOGICOR FIN LOGICR 3.25 11/13/28', 'company_name: Emirates NBD Bank PJSC', 'company_name: PRUDENTIAL FINANCIAL INC', 'company_name: Home Depot Inc/The', 'company_name: JPMORGAN CHASE & CO', 'company_name: KWEICHOW MOUTAI CO LTD-A', 'company_name: Pembina Pipeline Corp', 'company_name: ARCH CAPITAL GRP ACGL 3.635 06/30/50', 'company_name: KONINKLIJKE AHOLD DELHAIZE N', 'company_name: KOMEDA HOLDINGS CO LTD', 'company_name: PETROBRAS GLOB PETBRA 5.093 01/15/30', 'company_name: Sappi Papier Holding GmbH', 'company_name: Taiwan Cement Corp', 'company_name: MEDIPAL HOLDINGS CORP', 'company_name: SOFTWARE AG', 'company_name: Howmet Aerospace Inc', 'company_name: COLLECTOR AB', 'company_name: CITY DEVELOPMENTS LTD', 'company_name: INTERTEK GROUP PLC', 'company_name: JM HOLDINGS CO LTD', 'company_name: Heartcore Capital Fund IV, 965YJV902', 'company_name: TECNICAS REUNIDAS SA', 'company_name: WATERSTONE FINANCIAL INC', 'company_name: Tanger Factory Outlet Centers Inc', 'company_name: BARCLAYS PLC BACR 7.125 PERP', 'company_name: OPPEIN HOME GROUP INC-A', 'company_name: STARTS CORP INC', 'company_name: MAX CO LTD', 'company_name: RXR RE Value Added Fund III (VAF III), 927ZHA904', 'company_name: Public Storage', 'company_name: ON Semiconductor Corp', 'company_name: MAGENTA THERAPEUTICS INC', 'company_name: ZIGEXN CO LTD', 'company_name: United Microelectronics Corp', 'company_name: ROYAL HOLDINGS CO LTD', 'company_name: Mayfield XVI, 966KLEII7', 'company_name: DBS GROUP HOLDINGS LTD', 'company_name: EVA GROUP PLC', 'company_name: ANHEUSER-BUSCH ABIBB 4.95 01/15/42', 'company_name: MBIA Insurance Corp', 'company_name: OIL REFINERIES LTD', 'company_name: AMCO SPA AMCOSP 0.75 04/20/28', 'company_name: NorthWestern Corp', 'company_name: Comerica Inc', 'company_name: LHC Group Inc', 'company_name: HAWAIIAN HOLDINGS INC', 'company_name: SUNAC CHINA HLDG SUNAC 7.5 02/01/24', 'company_name: Bangkok Expressway & Metro PCL', 'company_name: NVR Inc', 'company_name: GEA GROUP AG', 'company_name: MERUS NV', 'company_name: Fiserv Inc', 'company_name: PepsiCo Inc', 'company_name: KINGSPAN GROUP PLC', 'company_name: Temenos AG', 'company_name: SHANDONG NANSHAN ALUMINUM-A', 'company_name: BOC AVIATION BOCAVI 2.375 09/15/21', 'company_name: Hamilton Lane Alliance Holdings I Inc', 'company_name: AXIATA GROUP BERHAD', 'company_name: Life Science Partner VI,933IAM905', 'company_name: TKP CORP', 'company_name: SSE PLC', 'company_name: HSBC HOLDINGS HSBC 3.973 05/22/30', 'company_name: LG HOUSEHOLD & HEALTH-PREF', 'company_name: JPW Industries Holding Corp', 'company_name: SOUTHERN CROSS MEDIA GROUP L', 'company_name: ATD New Holdings Inc', 'company_name: Pinterest Inc', 'company_name: EGUARANTEE INC', 'company_name: BAYWA-BAYERISCHE WARENVERMIT', 'company_name: City Developments Ltd', 'company_name: GERON CORP', 'company_name: SANLORENZO SPA/AMEGLIA', 'company_name: DAIBIRU CORP', 'company_name: PROGRESS SOFTWARE CORP', 'company_name: MAXELL HOLDINGS LTD', 'company_name: Digital Turbine Inc', 'company_name: Globant SA', 'company_name: NANKAI ELECTRIC RAILWAY CO', 'company_name: HOSIDEN CORP', 'company_name: GO ...

# %%
fund_names =set([remove_company_name(row[1])  for row in fund_data])#set function will not allow duplicates
print(fund_names) #remove_company_name() takes row as a argument and remove the company name and print the data
# Out:
# {None}

# %%
def remove_company_name(company_cell):
    return company_cell.replace('company_name: ', '')

# %%
#fund_names =set([row[1] for row in fund_data])
for row in fund_data:
    modified_company_name = remove_company_name(row[1])
    row[1]= modified_company_name
print(fund_data)
# Out:
# [['AkademikerPension', 'ANDRITZ AG', '9035889.67000961'], ['AkademikerPension', 'Verbund AG', '535484.04264'], ['AkademikerPension', 'Wienerberger AG', '489278.539054215'], ['AkademikerPension', 'ams AG', '9582835.98899249'], ['AkademikerPension', 'Oesterreichische Post AG', '283768.092184449'], ['AkademikerPension', 'Pendal Group Ltd', '1279011.44099595'], ['AkademikerPension', 'Asaleo Care Ltd', '311739.24'], ['AkademikerPension', 'Aristocrat Leisure Ltd', '159265.740991766'], ['AkademikerPension', 'ALS Ltd', '10314327.76'], ['AkademikerPension', 'Altium Ltd', '14675679.27'], ['AkademikerPension', 'AMP Ltd', '210881.09'], ['AkademikerPension', 'AUST AND NZ BANKING GROUP', '15375.58598142'], ['AkademikerPension', 'Australia & New Zealand Banking Group Ltd', '723352.74'], ['AkademikerPension', 'Afterpay Ltd', '52173246.8698483'], ['AkademikerPension', 'ARB Corp Ltd', '1264033.30473119'], ['AkademikerPension', 'Aurizon Holdings Ltd', '464861.38'], ['AkademikerPension', 'BHP Group Ltd', '864932.15'], ['AkademikerPension', 'BlueScope Steel Ltd', '917444.99'], ['AkademikerPension', 'Brambles Ltd', '27064700.0083148'], ['AkademikerPension', 'carsales.com Ltd', '7762697.73'], ['AkademikerPension', 'Challenger Ltd', '102934.07'], ['AkademikerPension', 'Sungard AS New Holdings III LLC', '86069.3048419842'], ['AkademikerPension', 'Superior Energy Services Inc', '4876.30308519994'], ['AkademikerPension', 'a2 Milk Co Ltd/The', '3541279.4'], ['AkademikerPension', 'Fisher & Paykel Healthcare Corp Ltd', '20645924.7901157'], ['AkademikerPension', 'Fletcher Building Ltd', '416220.93'], ['AkademikerPension', 'SKY Network Television Ltd', '94699.0000000001'], ['AkademikerPension', 'Xero Ltd', '55058026.5397112'], ['AkademikerPension', 'Copa Holdings SA', '26475067.0386764'], ['AkademikerPension', 'Ayala Land Inc', '21203523.018685'], ['AkademikerPension', 'BANK OF THE PHILIPPINE ISLAN', '60200.1842401783'], ['AkademikerPension', 'Bank of the Philippine Islands', '8026691.23537698'], ['AkademikerPension', 'GT Capital Holdings Inc', '509884.860641693'], ['AkademikerPension', 'FIRST BANCORP PUERTO RICO', '23846.623908'], ['AkademikerPension', 'First BanCorp/Puerto Rico', '4841240.7'], ['AkademikerPension', 'Popular Inc', '4323906.8552835'], ['AkademikerPension', 'Jeronimo Martins SGPS SA', '486822.302129009'], ['AkademikerPension', 'Alrosa PJSC', '804648.459918326'], ['AkademikerPension', 'Sberbank of Russia PJSC', '19143639.6143176'], ['AkademikerPension', 'SKF AB', '13273406.6633907'], ['AkademikerPension', 'Telefonaktiebolaget LM Ericsson', '161110047.305397'], ['AkademikerPension', 'Skanska AB', '5239693.04'], ['AkademikerPension', 'Trelleborg AB', '6148926.74'], ['AkademikerPension', 'Volvo AB', '33971461.6960737'], ['AkademikerPension', 'SSAB AB', '3869236.51'], ['AkademikerPension', 'Skandinaviska Enskilda Banken AB', '40280221.8488569'], ['AkademikerPension', 'Getinge AB', '262223.69'], ['AkademikerPension', 'Modern Times Group MTG AB', '119935.100307132'], ['AkademikerPension', 'Sandvik AB', '20269610.1958841'], ['AkademikerPension', 'Cellavision AB', '2530996.36'], ['AkademikerPension', 'BillerudKorsnas AB', '5760095.79'], ['AkademikerPension', 'INVISIO AB', '4402581.34'], ['AkademikerPension', 'Fortnox AB', '2416749.11'], ['AkademikerPension', 'Genovis AB', '3483834.05'], ['AkademikerPension', 'Xvivo Perfusion AB', '4466050.02'], ['AkademikerPension', 'Inwido AB', '6752577.04'], ['AkademikerPension', 'Assa Abloy AB', '1388916.78130948'], ['AkademikerPension', 'Svenska Handelsbanken AB', '3356745.01500966'], ['AkademikerPension', 'MIPS AB', '11311639.59'], ['AkademikerPension', 'Boozt AB', '29385069.3'], ['AkademikerPension', 'Essity AB', '30398980.0542549'], ['AkademikerPension', 'Arjo AB', '11028859.29'], ['AkademikerPension', 'BHG Group AB', '3301043.9'], ['AkademikerPension', 'Atlas Copco AB', '91465322.4580255'], ['AkademikerPension', 'Nordic Entertainment Group AB', '307669.25'], ['AkademikerPension', 'Avanza Bank Holding AB', '917 ...

# %%
import math

def new_invested_amount(fund_data):
     for row in fund_data:
        if row[0]==akadamikerpension:
            new_amount= round(float(row[2]))
            row[2]=new_amount
        elif row[0]==industriespension:
            formatted_amount= int(float(row[2])*1000000)
            row[2]=formatted_amount
        
        return fund_data

# %%
pension_fund =set([remove_company_name(row[2])  for row in fund_data])
print(pension_fund)
# Out:
# {'1311394.40666493', '8757983.95917017', '9564116.6241585', '282982', '284964', '994577', '7929326.06', '378', '7234404', '230045', '60141', '16665694.498437', '4394412', '999084', '121091', '207815', '308987', '42310309.1514015', '301816', '186', '58481871.6824238', '194173764.577895', '410579516.634966', '735242.124311651', '2218077', '264103', '190632', '173410', '89421', '1078819', '18181718.8803729', '215906', '1190288', '191', '1690740', '276817', '978318', '195872', '97358', '1016576', '287', '1020037.7196', '230392', '5527932.152598', '2455531', '1029058', '27744361.5877686', '223892', '317232', '16030972.7288146', '227926', '201458', '1139349.61', '108608', '6440730', '227', '169018', '308
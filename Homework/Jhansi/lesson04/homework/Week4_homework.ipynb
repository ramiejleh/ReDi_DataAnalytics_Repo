# %% [markdown]
# #### Hi! Today you will play with NaN values and another Data Manipulation methods. Let us know if you need help and also if you need more challenges on that :)

# %% [markdown]
# #### The dataset that you will use is again recipes.csv. You can either use your own or the one in the subfolder "data". Do not forget to import the necessary libraries!

# %%
import pandas as pd
import numpy as np
recipes_nw = pd.read_csv("data/recipes.csv", index_col=0)
recipes_nw.head()
# Out:
#    vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0        True        True       True        False          1.0
# 1        True        True      False        False          0.0
# 2       False       False      False        False          3.0
# 3        True       False       True        False          2.0
# 4       False        True      False        False         31.0
#
#    aggregateLikes      id                                    title  \
# 0               3  633998                Banana Blueberry Pancakes
# 1               1  634426  Basil and Orange Confit Compound Butter
# 2               1  635085                 Black Bottom Banana Bars
# 3               1  663229      The Best Raw Chocolate Chip Cookies
# 4               3  651437      Mediterranean Spinach Artichoke Dip
#
#    pricePerServing  readyInMinutes  ...  VitaminB3Amount  \
# 0            55.79              45  ...             0.49
# 1            15.07              45  ...              NaN
# ...

# %% [markdown]
# #### Print the names of Columns that have null values

# %%
nan_values = recipes_nw.isna()
nan_columns = nan_values.any()

columns_with_nan = recipes_nw.columns[nan_columns].tolist()
print(columns_with_nan)
# Out:
# ['FiberAmount', 'FiberpercentOfDailyNeed', 'VitaminB6Amount', 'VitaminB6percentOfDailyNeed', 'ManganeseAmount', 'ManganesepercentOfDailyNeed', 'SeleniumAmount', 'SeleniumpercentOfDailyNeed', 'PotassiumAmount', 'PotassiumpercentOfDailyNeed', 'VitaminB2Amount', 'VitaminB2percentOfDailyNeed', 'VitaminCAmount', 'VitaminCpercentOfDailyNeed', 'PhosphorusAmount', 'PhosphoruspercentOfDailyNeed', 'FolateAmount', 'FolatepercentOfDailyNeed', 'VitaminB5Amount', 'VitaminB5percentOfDailyNeed', 'MagnesiumAmount', 'MagnesiumpercentOfDailyNeed', 'IronAmount', 'IronpercentOfDailyNeed', 'VitaminKAmount', 'VitaminKpercentOfDailyNeed', 'CopperAmount', 'CopperpercentOfDailyNeed', 'VitaminAAmount', 'VitaminApercentOfDailyNeed', 'VitaminB12Amount', 'VitaminB12percentOfDailyNeed', 'VitaminDAmount', 'VitaminDpercentOfDailyNeed', 'ZincAmount', 'ZincpercentOfDailyNeed', 'VitaminEAmount', 'VitaminEpercentOfDailyNeed', 'VitaminB3Amount', 'VitaminB3percentOfDailyNeed', 'VitaminB1Amount', 'VitaminB1percentOfDailyNe
# ...

# %% [markdown]
# #### Print the recipes with the highest number of aggregateLikes

# %%
#recipes_nw['aggregateLikes']. max()
# index corresponding max value
i = recipes_nw['aggregateLikes'].idxmax()
print(i)
# display the name corresponding this index
print(recipes_nw['title'][i])
# Out:
# 50
# Slow Cooker Spicy Hot Wings

# %% [markdown]
# #### Handle the missing values of “calcium percent of Daily need”. Sort the resulting DataFrame by id column.

# %%
### the goal is to fill in a value for the rows that dont have a value
### in the example below the median of the column is determined and fille in place where 
### the CalciumpercentOfDailyNeed is not avaliable
### value_to_fill = recipes_nw.CalciumpercentOfDailyNeed.median()
### new_df = recipes_nw.copy()
### new_df.CalciumpercentOfDailyNeed.fillna(value_to_fill, inplace=True)

#recipes_nw['CalciumpercentOfDailyNeed'].fillna(recipes_nw['CalciumpercentOfDailyNeed'].median(), inplace=True)
recipes_nw.fillna(recipes_nw.mean())
# Out:
# C:\Users\jhansi\AppData\Local\Temp/ipykernel_10280/3876468209.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   recipes_nw.fillna(recipes_nw.mean())
#      vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0          True        True       True        False          1.0
# 1          True        True      False        False          0.0
# 2         False       False      False        False          3.0
# 3          True       False       True        False          2.0
# 4         False        True      False        False         31.0
# ..          ...         ...        ...          ...          ...
# 145       False        True       True        False         18.0
# 146        True       False      False        False          1.0
# 147        True        True       True         True         93.0
# ...

# %% [markdown]
# #### Delete the columns that have null values == 141

# %%
### task is to find and delete columns with null values that sum = 141
### a more elegant and readable solution is 
### col_to_drop = [col for col in df.columns if df[col].isnull().sum() == 141]
### df.drop(col_to_drop, axis=1)

# %% [markdown]
# #### Print the title of the recipes that are vegetarian == TRUE and glutenFree == True

# %%
df=recipes_nw.loc[(recipes_nw.vegetarian == True) & (recipes_nw.glutenFree == True),"title"]
df
# Out:
# 0                              Banana Blueberry Pancakes
# 1                Basil and Orange Confit Compound Butter
# 14                            Spicy Carrot Amaranth Soup
# 15                                            Nutty Rice
# 20                           Fire Roasted Tomato Chutney
# 22                                 Butternut Squash Soup
# 24                         Green Beans with Garlic Chips
# 27                                Easy Eggplant Parmesan
# 29                                            Kappa Maki
# 30                              Vegan Chana Masala Curry
# 31     Grilled Peach Melba with Vanilla Bean Frozen Y...
# 33                             Detox Orange Carrot Juice
# 37                      Roasted Asparagus with Egg Salad
# 39                   Three Ingredient Frozen Pina Colada
# 42                               Peach Coconut Ice Cream
# 57     Sautéed Balsamic Green Beans With Cherry Tomatoes
# ...

# %% [markdown]
# #### How many vegan recipes are there (Vegan = Vegetarian and dairy free)?

# %%
vegan_recipes=recipes_nw.loc[(recipes_nw.vegetarian == True) & (recipes_nw.dairyFree == True)]
len(vegan_recipes)
# Out:
# 29

# %% [markdown]
# #### Compare the average amount of Vitamin B12 for the vegan and non-vegan recipes. How reliable are the results?

# %%
vitamin_B12_vegan=recipes_nw[recipes_nw.vegetarian == True]
vitamin_B12_vegan = vitamin_B12_vegan.VitaminB12Amount.mean() 
vitamin_B12_non_vegan=recipes_nw[recipes_nw.vegetarian == False]
vitamin_B12_non_vegan = vitamin_B12_non_vegan.VitaminB12Amount.mean() 
print('Avg amount of Vitamin B12 for vegan recipes is: ' + str(vitamin_B12_vegan))
print('Avg amount of Vitamin B12 for vegan recipes is: ' + str(vitamin_B12_non_vegan))
# Out:
# Avg amount of Vitamin B12 for vegan recipes is: 0.48357142857142854
# Avg amount of Vitamin B12 for vegan recipes is: 1.235384615384615

# %% [markdown]
# #### Compare the average health Score for both types of recipes (vegan vs non-vegan).

# %%
B12_vegan=recipes_nw[recipes_nw.vegetarian == True].healthScore.mean()
B12_vegan
# Out:
# 18.484848484848484

# %%
B12_non_vegan=recipes_nw[recipes_nw.vegetarian == False].healthScore.mean()
B12_non_vegan
# Out:
# 22.107142857142858

# %% [markdown]
# #### Create a new column: "VeganWeek" where you decrease the price of vegan products by 10%, but only if they already cost more than 100.

# %%
recipes_nw[VeganWeek] = np.where(recipes_nw(pricePerServing > 100),(recipes_nw.pricePerServing)*0.9, (recipes_nw.pricePerServing)*1)
recipes_nw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10280/1262516636.py in <module>
# ----> 1 recipes_nw[VeganWeek] = np.where(recipes_nw(pricePerServing > 100),(recipes_nw.pricePerServing)*0.9, (recipes_nw.pricePerServing)*1)
#       2 recipes_nw
#
# NameError: name 'pricePerServing' is not defined

# %% [markdown]
# #### Among the non-vegan recipes, find the one requiring most time to prepare. How is it called?

# %%
df =recipes_nw.loc[(recipes_nw.vegetarian == False),'title'][recipes_nw.readyInMinutes == recipes_nw['readyInMinutes'].max()]

df
# Out:
# 83    Oeufs En Meurette
# Name: title, dtype: object

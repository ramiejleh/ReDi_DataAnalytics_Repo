# %% [markdown]
# #### Time for an exercise session on the Data Manipulation. We will continue working with the wine dataset.
#
# Columns in the dataset:
# - "country": Country of which the wine was produced
# - "description": Description of the taste (qualitative)
# - "designation": Amount of points a profesisonal wine taster rated the wine
# - "points": Points rated by the wine taster (quantitative)
# - "price": Selling price of the wine
# - "province": Province of the country which the wine originates from
# - "region_1": One entry of which region the wine originates from
# - "region_2": Another entry of which region the wine originates from
# - "taster_name": Name of the professional wine taster who rated the wine
# - "taster_twitter_handle": Twitter username of the professional wine taster
# - "title": Competition of which the wine taster tasted the wine
# - "variety": Category of wine

# %% [markdown]
# #### Start with loading the dataset from the data subfolder

# %%
import pandas as pd
import numpy as np

# %%
filename = 'data/wine.csv'

df = pd.read_csv(filename, index_col = 0)

df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# #### Check if there are any wines from Italy which did not score more than 85 points.

# %%
#Lession with Rami 

#how to Google: 'a subset dataframe based on condition'
#how to Google: get a column from dataframe with conditions 
#how to Google: filter dataframe based on a condition 

filtered = df[df['country'] == 'Italy']
filtered
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
filtered_point = df[df[filtered]['points'] > 85]
filtered_point
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30480/1186065506.py in <module>
# ----> 1 filtered_point = df[df[filtered]['points'] > 85]
#       2 filtered_point
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3443         # Do we have a (boolean) DataFrame?
#    3444         if isinstance(key, DataFrame):
# -> 3445             return self.where(key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
filtered_2_conditions = df[(df['country'] == 'Italy') & (df['points'] <= 85)]
filtered_2_conditions

# %%
#Solution with 2 step:

#Step 1: 

is_from_italy = df['country'] == 'Italy'
italy_wines = df[is_from_italy] 

#Step 2: 
is_less_than_85 = italy_wines['points'] <= 85 
satisfied = italy_wines[is_less_than_85]

satisfied

# %%
#Another solution with loc

new_df = df.loc[(df.country == 'Italy') & (df.points <=85)]
new_df

# %%
#a mask 


mask = df['country']=='Italy' 

##result = df[mask]

mask_condition2 = df['points'] > 85 

result = df[mask & mask_condition2]

result

##result.shape

# result = df[(df['country']=='Italy') & (df['price'] <= 85)]

# if you replace & with |, meaning the condition has to satisfy one of them

# %% [markdown]
# #### If there are some, which variety is most represented among them? Please do not copy the name that you "see" has the greatest representation, but rather extract it from the dataset. Remember: Copying enhances the change of a human mistake!

# %%
#Lession with Rami:

ser = new_df['variety'].value_counts(ascending=True)

ser.nlargest().index[0]

#new_df['variety'].value_counts.idxmax()

# %%
result

# %%
grouped = result.groupby(by=['variety']).count() 

grouped['country'].sort_values()

#grouped_max_count = result.groupby(by=['variety']).sort()

#reset the dataframe
grouped = grouped.reset_index() #['variety']#.sort_values()

grouped = grouped[['variety','country']]
grouped

# %% [markdown]
# #### Since this variety has been rated so poorly...
# - We reduce the price for all the Italian wines from this variety by 20%...
# - ... and create a new columns called "sales_title", adding: "SALE " in the beginning of each Title for these wines and "NOT ON SALE" to the remaining ones.

# %%
#check 'Red blend' is only in Italian wine

df.loc[df.variety == 'Red Blend']

# Turns out Red Blend is not only Italian wine.
# Out:
#           country                                        description  \
# 20             US  Ripe aromas of dark berries mingle with ample ...
# 28          Italy  Aromas suggest mature berry, scorched earth, a...
# 31          Italy  Merlot and Nero d'Avola form the base for this...
# 33             US  Rustic and dry, this has flavors of berries, c...
# 45             US  Right out of the starting blocks this is an oa...
# ...           ...                                                ...
# 129925  Argentina  A lively, well-made blend of Tempranillo, Malb...
# 129928      Spain  This represents Torres' highest effort in Prio...
# 129932  Argentina  Andeluna's top wines tend to be ripe and plump...
# 129943      Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947      Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
#
#                          designation  points  price           province  \
# ...

# %%
df.loc[(df.variety == 'Red Blend') & (df.country == 'Italy'), 'price'] = df.price*.8 


#now gg: change based on condition pandas 
#Use the condition as a reference to check values 
#df.loc[(df.variety == 'Red Blend') & (df.country == 'Italy')]

# %%
#Check italian 'red blend' wine, score>=85 
df['price'] = np.where((df['country'] == 'Italy') & (df['variety'] == 'Red Blend'), (df['price'])*0.8, (df['price'])*1)
#np.where returns a numpy array 

#df['price'] = np.where((df.country == 'Italy') & (df.variety == 'Red Blend'), (df['price'])*0.8, (df['price'])*1)

# %%
#
df['salestitle'] = np.where((df['country'] == 'Italy') & (df['variety'] == 'Red Blend'), 'SALES ' + df['title'], 'NOT ON SALES ' + df['title'])

#df['salestitle'] = np.where((df.country == 'Italy') & (df.variety == 'Red Blend'), 'SALES ' + df.title, 'NOT ON SALES ' + df.title)
#np.where is a method, so it starts with a parenthesis and closes with a parenthesis
#if value to append is numeric, then convert to string: for example: df1['State_new'] ='USA-' + df1['State'].astype(str)
df.loc[(df.variety == 'Red Blend') & (df.country == 'Italy')]
# Out:
#        country                                        description  \
# 28       Italy  Aromas suggest mature berry, scorched earth, a...
# 31       Italy  Merlot and Nero d'Avola form the base for this...
# 50       Italy  This blend of Nero d'Avola and Syrah opens wit...
# 54       Italy  A blend of Nero d'Avola and Nerello Mascalese,...
# 104      Italy  Made with 65% Sangiovese, 20% Merlot and 15% C...
# ...        ...                                                ...
# 129692   Italy  This has aromas of raisin, fig and espresso. T...
# 129699   Italy  This offers fruity and spicy fragrances of bla...
# 129735   Italy  Dark-skinned berry, Mediterranean herb and for...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
#
#                          designation  points      price           province  \
# 28                Mascaria Barricato      87   4.456448  Sicily & Sardinia
# ...

# %%
df.drop(['price2'],axis = 1)
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...
